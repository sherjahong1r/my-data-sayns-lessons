# %% [markdown]
# <a href="https://colab.research.google.com/github/sherjahong1r/my-data-sayns-lessons/blob/main/03_04_05_row_column_iyerarxik_idx_and_they_change.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Ma'lumotlar to'plami ustida iyerarxik indekslash**

# %% [markdown]
# ## *Dunyo shaharlarining havo va suv sifati ma'lumotlari ustida amallar bajarish*

# %%
import pandas as pd
import numpy as np

# %%
url = ('https://github.com/MansurCompAI/Practicum_Datasets')
pd.read_html(url)
# githubdan html formatida o'qish
# Out:
# [                                 Name                              Name.1  \
#  0     Latest commit History17 Commits     Latest commit History17 Commits
#  1                       GM_Uzbekistan                       GM_Uzbekistan
#  2                           Happiness                           Happiness
#  3                                IMDb                                IMDb
#  4                           README.md                           README.md
#  5                            bank.csv                            bank.csv
#  6                      data_pivot.csv                      data_pivot.csv
#  7  world_cities_air_water_quality.csv  world_cities_air_water_quality.csv
#  8                      View all files                      View all files
#
#                                 Name.2  Last commit message  Last commit date
#  0     Latest commit History17 Commits                  NaN               NaN
# ...

# %%
# !git clone https://github.com/MansurCompAI/Practicum_Datasets.git
# git clone bilan kaggle dan o'qish
# Out:
# Cloning into 'Practicum_Datasets'...
# remote: Enumerating objects: 60, done.
# remote: Counting objects: 100% (60/60), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 60 (delta 17), reused 16 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (60/60), 20.24 MiB | 12.42 MiB/s, done.
# Resolving deltas: 100% (17/17), done.

# %%
df = pd.read_csv("/content/Practicum_Datasets/world_cities_air_water_quality.csv")
df
# Bu yerdagi silkani !git clone qilganimizdan so'ng chap tomondagi fayylarda
# world_cities_air_water_qualification kabi bir nechta fayllar chiqib turadi uning ustiga o'ng tugmani
# bosib copy path qilsak silkasi copy bo'ladi
# Out:
#                   City                 "Region"                    "Country"  \
# 0        New York City               "New York"   "United States of America"
# 1     Washington, D.C.   "District of Columbia"   "United States of America"
# 2        San Francisco             "California"   "United States of America"
# 3               Berlin                       ""                    "Germany"
# 4          Los Angeles             "California"   "United States of America"
# ...                ...                      ...                          ...
# 3958             Yanbu        "Medina Province"               "Saudi Arabia"
# 3959           Cordoba              "Andalusia"                      "Spain"
# 3960               Vic              "Catalonia"                      "Spain"
# 3961           Segovia       "Castile and Leon"                      "Spain"
# 3962       Zamora city       "Castile and Leon"                      "Spain"
#
#        "AirQuality"   "WaterPollution"
# ...

# %%
df1 = pd.read_csv("/content/Practicum_Datasets/bank.csv")
df1
# Huddi shunday qolgan fayllarni ham yuklab olishimiz mumkin
# Out:
#      age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# 0     30;"unemployed";"married";"primary";"no";1787;...
# 1     33;"services";"married";"secondary";"no";4789;...
# 2     35;"management";"single";"tertiary";"no";1350;...
# 3     30;"management";"married";"tertiary";"no";1476...
# 4     59;"blue-collar";"married";"secondary";"no";0;...
# ...                                                 ...
# 4516  33;"services";"married";"secondary";"no";-333;...
# 4517  57;"self-employed";"married";"tertiary";"yes";...
# 4518  57;"technician";"married";"secondary";"no";295...
# 4519  28;"blue-collar";"married";"secondary";"no";11...
# 4520  44;"entrepreneur";"single";"tertiary";"no";113...
#
# [4521 rows x 1 columns]

# %%
df
# Out:
#                   City                 "Region"                    "Country"  \
# 0        New York City               "New York"   "United States of America"
# 1     Washington, D.C.   "District of Columbia"   "United States of America"
# 2        San Francisco             "California"   "United States of America"
# 3               Berlin                       ""                    "Germany"
# 4          Los Angeles             "California"   "United States of America"
# ...                ...                      ...                          ...
# 3958             Yanbu        "Medina Province"               "Saudi Arabia"
# 3959           Cordoba              "Andalusia"                      "Spain"
# 3960               Vic              "Catalonia"                      "Spain"
# 3961           Segovia       "Castile and Leon"                      "Spain"
# 3962       Zamora city       "Castile and Leon"                      "Spain"
#
#        "AirQuality"   "WaterPollution"
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3963 entries, 0 to 3962
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   City               3963 non-null   object
#  1    "Region"          3963 non-null   object
#  2    "Country"         3963 non-null   object
#  3    "AirQuality"      3963 non-null   float64
#  4    "WaterPollution"  3963 non-null   float64
# dtypes: float64(2), object(3)
# memory usage: 154.9+ KB

# %%
columns = ['City', 'Region', 'Country', 'AirQuality', 'WaterPollution']
df.columns = columns
df
# Etibor bersak City dan tashqari qolgan ustunlar qo'shtirnoq ichida edi
# uni to'g'irlash uchun hammasiga qaytadan nom berdik
# Out:
#                   City                   Region                      Country  \
# 0        New York City               "New York"   "United States of America"
# 1     Washington, D.C.   "District of Columbia"   "United States of America"
# 2        San Francisco             "California"   "United States of America"
# 3               Berlin                       ""                    "Germany"
# 4          Los Angeles             "California"   "United States of America"
# ...                ...                      ...                          ...
# 3958             Yanbu        "Medina Province"               "Saudi Arabia"
# 3959           Cordoba              "Andalusia"                      "Spain"
# 3960               Vic              "Catalonia"                      "Spain"
# 3961           Segovia       "Castile and Leon"                      "Spain"
# 3962       Zamora city       "Castile and Leon"                      "Spain"
#
#       AirQuality  WaterPollution
# ...

# %%
# Yuqoridagi jadvalga etibor bersak Region ustunidagi qatorlar qo'shtirnoq ichiga yozilgan
df['Region'] = df['Region'].map(lambda x: x.replace('"', ''))
df
# Buni yo'q qilish uchun .map bilan yani u ma'lumotlarni tozalash, formatlash uchun  Pandas DataFrame ustunidagi
# (Series obyekti) har bir elementga biror funksiyani qo'llash uchun ishlatiladi.
# map ichida lambda bilan hamma qiymatlarni x qiladi va uni yani bu x qiymatlarni x.replace yani almashtirish degani
# u bilan bir qo'sh tirnoq ichidagi qo'shtirnoqli qatorlar degani va uni almashtiradi verguldan keyingi natijaga yani
# u bir tirnoq ichida hech narsa bo'lmagani uchun qo'shtirnoqlarni tashlab yuboradi qiymatlardan.
# Out:
#                   City                 Region                      Country  \
# 0        New York City               New York   "United States of America"
# 1     Washington, D.C.   District of Columbia   "United States of America"
# 2        San Francisco             California   "United States of America"
# 3               Berlin                                           "Germany"
# 4          Los Angeles             California   "United States of America"
# ...                ...                    ...                          ...
# 3958             Yanbu        Medina Province               "Saudi Arabia"
# 3959           Cordoba              Andalusia                      "Spain"
# 3960               Vic              Catalonia                      "Spain"
# 3961           Segovia       Castile and Leon                      "Spain"
# 3962       Zamora city       Castile and Leon                      "Spain"
#
#       AirQuality  WaterPollution
# 0      46.816038       49.504950
# ...

# %%
df['Country'] = df['Country'].map(lambda x: x.replace('"', ''))
df
# Endi Country ustunidan ham qo'sh tirnoqlarni olib tashladik
# Out:
#                   City                 Region                    Country  \
# 0        New York City               New York   United States of America
# 1     Washington, D.C.   District of Columbia   United States of America
# 2        San Francisco             California   United States of America
# 3               Berlin                                           Germany
# 4          Los Angeles             California   United States of America
# ...                ...                    ...                        ...
# 3958             Yanbu        Medina Province               Saudi Arabia
# 3959           Cordoba              Andalusia                      Spain
# 3960               Vic              Catalonia                      Spain
# 3961           Segovia       Castile and Leon                      Spain
# 3962       Zamora city       Castile and Leon                      Spain
#
#       AirQuality  WaterPollution
# 0      46.816038       49.504950
# ...

# %%
df.to_csv("Updated_dataset.csv", index=False)
# index=False bu yana o'qiyotganda index ustuni qo'shilishini oldini oladi.
# buni yuqoridagi ayrim tahrirlash bilan yana saqlab oldik Updated_dataset.csv degan nom bilan

# %%
df2 = pd.read_csv('/content/Updated_dataset.csv')
df2
# yuqoridagi saqlab olgan Updated_dataset.csv ni copy path orqali olgan url bilan yana o'qib df2 ga saqladik
# Out:
#                   City                 Region                    Country  \
# 0        New York City               New York   United States of America
# 1     Washington, D.C.   District of Columbia   United States of America
# 2        San Francisco             California   United States of America
# 3               Berlin                                           Germany
# 4          Los Angeles             California   United States of America
# ...                ...                    ...                        ...
# 3958             Yanbu        Medina Province               Saudi Arabia
# 3959           Cordoba              Andalusia                      Spain
# 3960               Vic              Catalonia                      Spain
# 3961           Segovia       Castile and Leon                      Spain
# 3962       Zamora city       Castile and Leon                      Spain
#
#       AirQuality  WaterPollution
# 0      46.816038       49.504950
# ...

# %%
df
# Out:
#                   City                 Region                    Country  \
# 0        New York City               New York   United States of America
# 1     Washington, D.C.   District of Columbia   United States of America
# 2        San Francisco             California   United States of America
# 3               Berlin                                           Germany
# 4          Los Angeles             California   United States of America
# ...                ...                    ...                        ...
# 3958             Yanbu        Medina Province               Saudi Arabia
# 3959           Cordoba              Andalusia                      Spain
# 3960               Vic              Catalonia                      Spain
# 3961           Segovia       Castile and Leon                      Spain
# 3962       Zamora city       Castile and Leon                      Spain
#
#       AirQuality  WaterPollution
# 0      46.816038       49.504950
# ...

# %%
df['Country'][2]
# Out:
# ' United States of America'

# %%
df[df['Country']=='Germany']
# Bunda Germaniyani chiqarmadi chunki Germaniyadan oldin space yani bo'shliq bor
# Out:
# Empty DataFrame
# Columns: [City, Region, Country, AirQuality, WaterPollution]
# Index: []

# %%
df[df['Country']==' Germany']
# Bunda space qilganimiz uchun chiqardi
# Out:
#                         City                   Region   Country  AirQuality  \
# 3                     Berlin                            Germany   62.364130
# 28                   Cologne   North Rhine-Westphalia   Germany   60.714286
# 40                      Bonn   North Rhine-Westphalia   Germany   82.812500
# 52                 Heilbronn        Baden-Wurttemberg   Germany   80.000000
# 76                    Aachen   North Rhine-Westphalia   Germany   70.454545
# ...                      ...                      ...       ...         ...
# 2693             Bad Waldsee        Baden-Wurttemberg   Germany  100.000000
# 2714  Weilheim in Oberbayern                  Bavaria   Germany  100.000000
# 2727                  Buckow              Brandenburg   Germany   87.500000
# 3942                  Erfurt                Thuringia   Germany   85.000000
# 3943  Garmisch-Partenkirchen                  Bavaria   Germany  100.000000
#
#       WaterPollution
# 3          28.612717
# ...

# %%
df['Country'] = df2['Country'].map(lambda x: x.strip())
df
# Bu bilan yani .strip() bilan davlatlar oldidagi bo'shliqlarni olib tashladik
# Out:
#                   City                 Region                   Country  \
# 0        New York City               New York  United States of America
# 1     Washington, D.C.   District of Columbia  United States of America
# 2        San Francisco             California  United States of America
# 3               Berlin                                          Germany
# 4          Los Angeles             California  United States of America
# ...                ...                    ...                       ...
# 3958             Yanbu        Medina Province              Saudi Arabia
# 3959           Cordoba              Andalusia                     Spain
# 3960               Vic              Catalonia                     Spain
# 3961           Segovia       Castile and Leon                     Spain
# 3962       Zamora city       Castile and Leon                     Spain
#
#       AirQuality  WaterPollution
# 0      46.816038       49.504950
# 1      66.129032       49.107143
# ...

# %%
df2[df['Country']=='Germany']
# bo'shliqlarni olganimiz Natijasi
# Out:
#                         City                   Region   Country  AirQuality  \
# 3                     Berlin                            Germany   62.364130
# 28                   Cologne   North Rhine-Westphalia   Germany   60.714286
# 40                      Bonn   North Rhine-Westphalia   Germany   82.812500
# 52                 Heilbronn        Baden-Wurttemberg   Germany   80.000000
# 76                    Aachen   North Rhine-Westphalia   Germany   70.454545
# ...                      ...                      ...       ...         ...
# 2693             Bad Waldsee        Baden-Wurttemberg   Germany  100.000000
# 2714  Weilheim in Oberbayern                  Bavaria   Germany  100.000000
# 2727                  Buckow              Brandenburg   Germany   87.500000
# 3942                  Erfurt                Thuringia   Germany   85.000000
# 3943  Garmisch-Partenkirchen                  Bavaria   Germany  100.000000
#
#       WaterPollution
# 3          28.612717
# ...

# %%
df[df['Country']=='Uzbekistan']
# Out:
#         City Region     Country  AirQuality  WaterPollution
# 21  Tashkent         Uzbekistan   56.451613       49.166667

# %% [markdown]
# ## pivot_table orqali irarxik indekslash

# %%
df
# Out:
#                   City                 Region                   Country  \
# 0        New York City               New York  United States of America
# 1     Washington, D.C.   District of Columbia  United States of America
# 2        San Francisco             California  United States of America
# 3               Berlin                                          Germany
# 4          Los Angeles             California  United States of America
# ...                ...                    ...                       ...
# 3958             Yanbu        Medina Province              Saudi Arabia
# 3959           Cordoba              Andalusia                     Spain
# 3960               Vic              Catalonia                     Spain
# 3961           Segovia       Castile and Leon                     Spain
# 3962       Zamora city       Castile and Leon                     Spain
#
#       AirQuality  WaterPollution
# 0      46.816038       49.504950
# 1      66.129032       49.107143
# ...

# %%
df.index
# Bular tartibli oddiy indexlar
# Out:
# RangeIndex(start=0, stop=3963, step=1)

# %%
# Yuqoridagi jadvalga etibor bersak bir davlatlar ko'p takrorlangan uning shaharlari ko'p bo'lhanligi uchun
# endi bunda davlatlarni irarxik yani index guruhi qilib qo'yamiz pivot_table yordamida

df3 = pd.pivot_table(df, index=['Country', 'City'], values=['AirQuality', 'WaterPollution'], aggfunc='mean')
df3

# Country (davlat) asosiy indeks bo'lib, uning ichida City (shahar) ikkilamchi indeks bo'ladi. Bu iyerarxik indekslashni (multi-index) hosil qiladi,
# ya'ni har bir davlat ostida uning shaharlari guruhlanadi. values=['AirQuality', 'WaterPollution']: Bu parametr qaysi ustunlardagi
# ma'lumotlar jamlanishini (aggregate) ko'rsatadi. aggfunc='mean': Bu parametr values da ko'rsatilgan ustunlarga qanday jamlash (aggregation)
# funksiyasi qo'llanilishini aniqlaydi.  qiymatlarining o'rtacha (mean) miqdorini hisoblaydi.
# Out:
#                       AirQuality  WaterPollution
# Country     City
# Afghanistan Andkhoy    50.000000       50.000000
#             Farah     100.000000        0.000000
#             Herat      43.750000       31.250000
#             Kabul      18.421053       81.060606
#             Kandahar    0.000000       75.000000
# ...                          ...             ...
# Zambia      Mansa      75.000000       25.000000
# Zimbabwe    Bindura    50.000000       75.000000
#             Bulawayo   67.857143       71.428571
#             Harare     38.461538       87.500000
#             Masvingo   25.000000       62.500000
#
# [3895 rows x 2 columns]

# %%
df3
# Out:
#                       AirQuality  WaterPollution
# Country     City
# Afghanistan Andkhoy    50.000000       50.000000
#             Farah     100.000000        0.000000
#             Herat      43.750000       31.250000
#             Kabul      18.421053       81.060606
#             Kandahar    0.000000       75.000000
# ...                          ...             ...
# Zambia      Mansa      75.000000       25.000000
# Zimbabwe    Bindura    50.000000       75.000000
#             Bulawayo   67.857143       71.428571
#             Harare     38.461538       87.500000
#             Masvingo   25.000000       62.500000
#
# [3895 rows x 2 columns]

# %%
df3.index
# Bu esa MultiIndex yani irarxik
# Out:
# MultiIndex([('Afghanistan',        'Andkhoy'),
#             ('Afghanistan',          'Farah'),
#             ('Afghanistan',          'Herat'),
#             ('Afghanistan',          'Kabul'),
#             ('Afghanistan',       'Kandahar'),
#             ('Afghanistan', 'Mazar-i-Sharif'),
#             (    'Albania',         'Ballsh'),
#             (    'Albania',         'Burrel'),
#             (    'Albania',         'Durres'),
#             (    'Albania',        'Elbasan'),
#             ...
#             (      'Yemen',          'Sanaa'),
#             (      'Yemen',         'Ta'izz'),
#             (     'Zambia',       'Chingola'),
#             (     'Zambia',          'Kitwe'),
#             (     'Zambia',         'Lusaka'),
#             (     'Zambia',          'Mansa'),
#             (   'Zimbabwe',        'Bindura'),
#             (   'Zimbabwe',       'Bulawayo'),
#             (   'Zimbabwe',         'Harare'),
#             (   'Zimbabwe',       'Masvingo')],
# ...

# %%
df3.loc[['Uzbekistan', 'Tajikistan', 'Germany']]
# Out:
#                           AirQuality  WaterPollution
# Country    City
# Uzbekistan Tashkent        56.451613       49.166667
# Tajikistan Dushanbe        41.666667       61.111111
# Germany    Aachen          70.454545       17.857143
#            Aalen           87.500000       50.000000
#            Abensberg      100.000000       50.000000
# ...                              ...             ...
#            Wilhelmshaven  100.000000       50.000000
#            Wolfsburg       96.875000        0.000000
#            Worms           60.000000      100.000000
#            Wuppertal       90.000000        0.000000
#            Zwickau         75.000000       50.000000
#
# [126 rows x 2 columns]

# %% [markdown]
# # **04-dars**

# %% [markdown]
# # **Iyerarxik ustunli ma'lumotlar to'plami**

# %%
df
# Out:
#                   City                 Region                   Country  \
# 0        New York City               New York  United States of America
# 1     Washington, D.C.   District of Columbia  United States of America
# 2        San Francisco             California  United States of America
# 3               Berlin                                          Germany
# 4          Los Angeles             California  United States of America
# ...                ...                    ...                       ...
# 3958             Yanbu        Medina Province              Saudi Arabia
# 3959           Cordoba              Andalusia                     Spain
# 3960               Vic              Catalonia                     Spain
# 3961           Segovia       Castile and Leon                     Spain
# 3962       Zamora city       Castile and Leon                     Spain
#
#       AirQuality  WaterPollution
# 0      46.816038       49.504950
# 1      66.129032       49.107143
# ...

# %%
df2
# Out:
#                   City                 Region                    Country  \
# 0        New York City               New York   United States of America
# 1     Washington, D.C.   District of Columbia   United States of America
# 2        San Francisco             California   United States of America
# 3               Berlin                                           Germany
# 4          Los Angeles             California   United States of America
# ...                ...                    ...                        ...
# 3958             Yanbu        Medina Province               Saudi Arabia
# 3959           Cordoba              Andalusia                      Spain
# 3960               Vic              Catalonia                      Spain
# 3961           Segovia       Castile and Leon                      Spain
# 3962       Zamora city       Castile and Leon                      Spain
#
#       AirQuality  WaterPollution
# 0      46.816038       49.504950
# ...

# %%
df3
# Out:
#                       AirQuality  WaterPollution
# Country     City
# Afghanistan Andkhoy    50.000000       50.000000
#             Farah     100.000000        0.000000
#             Herat      43.750000       31.250000
#             Kabul      18.421053       81.060606
#             Kandahar    0.000000       75.000000
# ...                          ...             ...
# Zambia      Mansa      75.000000       25.000000
# Zimbabwe    Bindura    50.000000       75.000000
#             Bulawayo   67.857143       71.428571
#             Harare     38.461538       87.500000
#             Masvingo   25.000000       62.500000
#
# [3895 rows x 2 columns]

# %%
df3.loc[['Uzbekistan', 'Tajikistan', 'Germany']]
# Out:
#                           AirQuality  WaterPollution
# Country    City
# Uzbekistan Tashkent        56.451613       49.166667
# Tajikistan Dushanbe        41.666667       61.111111
# Germany    Aachen          70.454545       17.857143
#            Aalen           87.500000       50.000000
#            Abensberg      100.000000       50.000000
# ...                              ...             ...
#            Wilhelmshaven  100.000000       50.000000
#            Wolfsburg       96.875000        0.000000
#            Worms           60.000000      100.000000
#            Wuppertal       90.000000        0.000000
#            Zwickau         75.000000       50.000000
#
# [126 rows x 2 columns]

# %%
# df3 = df2.copy()
# copy qilib oldik yani df2 ham df3 ham bir hil bo'ladi

# %%
# df3

# %%
df3['AirPollution'] = 100-df3['AirQuality']
df3
# AirPollutionga saqlanayabdi 100 dan ayrilgan df3 AirQuality qiymatlari

# bu iyerarxik qilgan jadvalimiz bo'lib
# Country - mamlakatlar, city - shaharlar.
# AirQuality - havo sifati bo'lsa, AirPollution - havo ifloslanishi hisoblanadi va shu ustunni hozir yaratdik
# Misol uchun Afganistanning Herat shahrida havo sifati 43.75 bo'lsa, ifloslanishi 56.25 yani 100 % lik meyordan olingan
# va ikkalasining yig'indisi 100 bo'ladi.
# WaterPollution esa suv ifloslanishi.
# Out:
#                       AirQuality  WaterPollution  AirPollution
# Country     City
# Afghanistan Andkhoy    50.000000       50.000000     50.000000
#             Farah     100.000000        0.000000      0.000000
#             Herat      43.750000       31.250000     56.250000
#             Kabul      18.421053       81.060606     81.578947
#             Kandahar    0.000000       75.000000    100.000000
# ...                          ...             ...           ...
# Zambia      Mansa      75.000000       25.000000     25.000000
# Zimbabwe    Bindura    50.000000       75.000000     50.000000
#             Bulawayo   67.857143       71.428571     32.142857
#             Harare     38.461538       87.500000     61.538462
#             Masvingo   25.000000       62.500000     75.000000
#
# [3895 rows x 3 columns]

# %%
df3['WaterQuality'] = 100-df3['WaterPollution']
df3
# Endi huudi yana shunday WaterQuality jadval ustuni qo'shildi
# Out:
#                       AirQuality  WaterPollution  AirPollution  WaterQuality
# Country     City
# Afghanistan Andkhoy    50.000000       50.000000     50.000000     50.000000
#             Farah     100.000000        0.000000      0.000000    100.000000
#             Herat      43.750000       31.250000     56.250000     68.750000
#             Kabul      18.421053       81.060606     81.578947     18.939394
#             Kandahar    0.000000       75.000000    100.000000     25.000000
# ...                          ...             ...           ...           ...
# Zambia      Mansa      75.000000       25.000000     25.000000     75.000000
# Zimbabwe    Bindura    50.000000       75.000000     50.000000     25.000000
#             Bulawayo   67.857143       71.428571     32.142857     28.571429
#             Harare     38.461538       87.500000     61.538462     12.500000
#             Masvingo   25.000000       62.500000     75.000000     37.500000
#
# [3895 rows x 4 columns]

# %%
df3 = pd.DataFrame(df3.values, index = df3.index, columns= [['AIR','AIR','WATER','WATER'], ['AirQuality','AirPollution','WaterQuality','WaterPollution']])
df3
# Bunda ustunlarni iyerarxik ko'rinishga o'tkazdik
# Out:
#                              AIR                     WATER
#                       AirQuality AirPollution WaterQuality WaterPollution
# Country     City
# Afghanistan Andkhoy    50.000000    50.000000    50.000000      50.000000
#             Farah     100.000000     0.000000     0.000000     100.000000
#             Herat      43.750000    31.250000    56.250000      68.750000
#             Kabul      18.421053    81.060606    81.578947      18.939394
#             Kandahar    0.000000    75.000000   100.000000      25.000000
# ...                          ...          ...          ...            ...
# Zambia      Mansa      75.000000    25.000000    25.000000      75.000000
# Zimbabwe    Bindura    50.000000    75.000000    50.000000      25.000000
#             Bulawayo   67.857143    71.428571    32.142857      28.571429
#             Harare     38.461538    87.500000    61.538462      12.500000
#             Masvingo   25.000000    62.500000    75.000000      37.500000
#
# ...

# %%
df3['AIR']
# Out:
#                       AirQuality  AirPollution
# Country     City
# Afghanistan Andkhoy    50.000000     50.000000
#             Farah     100.000000      0.000000
#             Herat      43.750000     31.250000
#             Kabul      18.421053     81.060606
#             Kandahar    0.000000     75.000000
# ...                          ...           ...
# Zambia      Mansa      75.000000     25.000000
# Zimbabwe    Bindura    50.000000     75.000000
#             Bulawayo   67.857143     71.428571
#             Harare     38.461538     87.500000
#             Masvingo   25.000000     62.500000
#
# [3895 rows x 2 columns]

# %%
df3["WATER"]
# Out:
#                       WaterQuality  WaterPollution
# Country     City
# Afghanistan Andkhoy      50.000000       50.000000
#             Farah         0.000000      100.000000
#             Herat        56.250000       68.750000
#             Kabul        81.578947       18.939394
#             Kandahar    100.000000       25.000000
# ...                            ...             ...
# Zambia      Mansa        25.000000       75.000000
# Zimbabwe    Bindura      50.000000       25.000000
#             Bulawayo     32.142857       28.571429
#             Harare       61.538462       12.500000
#             Masvingo     75.000000       37.500000
#
# [3895 rows x 2 columns]

# %%
df3
# Out:
#                              AIR                     WATER
#                       AirQuality AirPollution WaterQuality WaterPollution
# Country     City
# Afghanistan Andkhoy    50.000000    50.000000    50.000000      50.000000
#             Farah     100.000000     0.000000     0.000000     100.000000
#             Herat      43.750000    31.250000    56.250000      68.750000
#             Kabul      18.421053    81.060606    81.578947      18.939394
#             Kandahar    0.000000    75.000000   100.000000      25.000000
# ...                          ...          ...          ...            ...
# Zambia      Mansa      75.000000    25.000000    25.000000      75.000000
# Zimbabwe    Bindura    50.000000    75.000000    50.000000      25.000000
#             Bulawayo   67.857143    71.428571    32.142857      28.571429
#             Harare     38.461538    87.500000    61.538462      12.500000
#             Masvingo   25.000000    62.500000    75.000000      37.500000
#
# ...

# %%
df3.columns.names = ['Object','Info']
df3
# Iyerarxik ustunlarga nom berish
# Out:
# Object                       AIR                     WATER
# Info                  AirQuality AirPollution WaterQuality WaterPollution
# Country     City
# Afghanistan Andkhoy    50.000000    50.000000    50.000000      50.000000
#             Farah     100.000000     0.000000     0.000000     100.000000
#             Herat      43.750000    31.250000    56.250000      68.750000
#             Kabul      18.421053    81.060606    81.578947      18.939394
#             Kandahar    0.000000    75.000000   100.000000      25.000000
# ...                          ...          ...          ...            ...
# Zambia      Mansa      75.000000    25.000000    25.000000      75.000000
# Zimbabwe    Bindura    50.000000    75.000000    50.000000      25.000000
#             Bulawayo   67.857143    71.428571    32.142857      28.571429
#             Harare     38.461538    87.500000    61.538462      12.500000
#             Masvingo   25.000000    62.500000    75.000000      37.500000
#
# ...

# %%
display(df3['AIR'])
# Out:
# Info                  AirQuality  AirPollution
# Country     City
# Afghanistan Andkhoy    50.000000     50.000000
#             Farah     100.000000      0.000000
#             Herat      43.750000     31.250000
#             Kabul      18.421053     81.060606
#             Kandahar    0.000000     75.000000
# ...                          ...           ...
# Zambia      Mansa      75.000000     25.000000
# Zimbabwe    Bindura    50.000000     75.000000
#             Bulawayo   67.857143     71.428571
#             Harare     38.461538     87.500000
#             Masvingo   25.000000     62.500000
#
# [3895 rows x 2 columns]

# %%
display(df3[('AIR', 'AirQuality')])
# Out:
# Country      City
# Afghanistan  Andkhoy      50.000000
#              Farah       100.000000
#              Herat        43.750000
#              Kabul        18.421053
#              Kandahar      0.000000
#                             ...
# Zambia       Mansa        75.000000
# Zimbabwe     Bindura      50.000000
#              Bulawayo     67.857143
#              Harare       38.461538
#              Masvingo     25.000000
# Name: (AIR, AirQuality), Length: 3895, dtype: float64

# %%
df3.index.names
# country va city indexlar nomi
# Out:
# FrozenList(['Country', 'City'])

# %%
df3.columns.names
# Object va Info columnlar nomi
# Out:
# FrozenList(['Object', 'Info'])

# %%
df3
# Out:
# Object                       AIR                     WATER
# Info                  AirQuality AirPollution WaterQuality WaterPollution
# Country     City
# Afghanistan Andkhoy    50.000000    50.000000    50.000000      50.000000
#             Farah     100.000000     0.000000     0.000000     100.000000
#             Herat      43.750000    31.250000    56.250000      68.750000
#             Kabul      18.421053    81.060606    81.578947      18.939394
#             Kandahar    0.000000    75.000000   100.000000      25.000000
# ...                          ...          ...          ...            ...
# Zambia      Mansa      75.000000    25.000000    25.000000      75.000000
# Zimbabwe    Bindura    50.000000    75.000000    50.000000      25.000000
#             Bulawayo   67.857143    71.428571    32.142857      28.571429
#             Harare     38.461538    87.500000    61.538462      12.500000
#             Masvingo   25.000000    62.500000    75.000000      37.500000
#
# ...

# %%
df3.loc[['Uzbekistan', 'Tajikistan']]
# Out:
# Object                     AIR                     WATER
# Info                AirQuality AirPollution WaterQuality WaterPollution
# Country    City
# Uzbekistan Tashkent  56.451613    49.166667    43.548387      50.833333
# Tajikistan Dushanbe  41.666667    61.111111    58.333333      38.888889

# %%
display(df3.loc[['Uzbekistan', 'Germany'], 'AIR'])
# Ham ustun ham qatordan belgilab chiqarish
# Out:
# Info                      AirQuality  AirPollution
# Country    City
# Uzbekistan Tashkent        56.451613     49.166667
# Germany    Aachen          70.454545     17.857143
#            Aalen           87.500000     50.000000
#            Abensberg      100.000000     50.000000
#            Amberg         100.000000     50.000000
# ...                              ...           ...
#            Wilhelmshaven  100.000000     50.000000
#            Wolfsburg       96.875000      0.000000
#            Worms           60.000000    100.000000
#            Wuppertal       90.000000      0.000000
#            Zwickau         75.000000     50.000000
#
# [125 rows x 2 columns]

# %%
display(df3.loc[['Germany'], ('AIR', 'AirQuality')])
# Out:
# Country  City
# Germany  Aachen                70.454545
#          Aalen                 87.500000
#          Abensberg            100.000000
#          Amberg               100.000000
#          Annaberg-Buchholz     87.500000
#                                  ...
#          Wilhelmshaven        100.000000
#          Wolfsburg             96.875000
#          Worms                 60.000000
#          Wuppertal             90.000000
#          Zwickau               75.000000
# Name: (AIR, AirQuality), Length: 124, dtype: float64

# %% [markdown]
# # ***05-dars***

# %% [markdown]
# # **.swaplevel(), sort_index()-iyerarxik indexli ma'lumotlarda indexlar o'rnini    almashtirish**

# %% [markdown]
# ## **Qayta tartiblash**

# %%
df3
# Bu yerda country ustuniga index deyiladi
# City ga subindex deyiladi
# shuningdek bularning leveli Country 0 indexda, City 1 - indexda joylashgan
# Out:
# Object                       AIR                     WATER
# Info                  AirQuality AirPollution WaterQuality WaterPollution
# Country     City
# Afghanistan Andkhoy    50.000000    50.000000    50.000000      50.000000
#             Farah     100.000000     0.000000     0.000000     100.000000
#             Herat      43.750000    31.250000    56.250000      68.750000
#             Kabul      18.421053    81.060606    81.578947      18.939394
#             Kandahar    0.000000    75.000000   100.000000      25.000000
# ...                          ...          ...          ...            ...
# Zambia      Mansa      75.000000    25.000000    25.000000      75.000000
# Zimbabwe    Bindura    50.000000    75.000000    50.000000      25.000000
#             Bulawayo   67.857143    71.428571    32.142857      28.571429
#             Harare     38.461538    87.500000    61.538462      12.500000
#             Masvingo   25.000000    62.500000    75.000000      37.500000
#
# ...

# %% [markdown]
# ## swaplevel

# %%
df3.swaplevel('Country','City')
# iyerarxik indexlarni o'rnini almashtirish
# Country va City ustuni o'rni almashtirildi etibor bersak har bir shahar qatoriga davlatlar yana qaytadan takrorlangan
# Out:
# Object                       AIR                     WATER
# Info                  AirQuality AirPollution WaterQuality WaterPollution
# City     Country
# Andkhoy  Afghanistan   50.000000    50.000000    50.000000      50.000000
# Farah    Afghanistan  100.000000     0.000000     0.000000     100.000000
# Herat    Afghanistan   43.750000    31.250000    56.250000      68.750000
# Kabul    Afghanistan   18.421053    81.060606    81.578947      18.939394
# Kandahar Afghanistan    0.000000    75.000000   100.000000      25.000000
# ...                          ...          ...          ...            ...
# Mansa    Zambia        75.000000    25.000000    25.000000      75.000000
# Bindura  Zimbabwe      50.000000    75.000000    50.000000      25.000000
# Bulawayo Zimbabwe      67.857143    71.428571    32.142857      28.571429
# Harare   Zimbabwe      38.461538    87.500000    61.538462      12.500000
# Masvingo Zimbabwe      25.000000    62.500000    75.000000      37.500000
#
# ...

# %% [markdown]
# ### sort_index

# %%
df3.sort_index(level=0, ascending=False)
# sort_index bilan yana jadvalni asl holatiga qaytaradi qavs ichidagi level=0 ni yani country ustunini
# ascending=False bilan teskari alifbe tartibida joylashtiradi. Dastlab jadval o'zi alifbe tartibida joylashgan edi
# Out:
# Object                       AIR                     WATER
# Info                  AirQuality AirPollution WaterQuality WaterPollution
# Country     City
# Zimbabwe    Masvingo   25.000000    62.500000    75.000000      37.500000
#             Harare     38.461538    87.500000    61.538462      12.500000
#             Bulawayo   67.857143    71.428571    32.142857      28.571429
#             Bindura    50.000000    75.000000    50.000000      25.000000
# Zambia      Mansa      75.000000    25.000000    25.000000      75.000000
# ...                          ...          ...          ...            ...
# Afghanistan Kandahar    0.000000    75.000000   100.000000      25.000000
#             Kabul      18.421053    81.060606    81.578947      18.939394
#             Herat      43.750000    31.250000    56.250000      68.750000
#             Farah     100.000000     0.000000     0.000000     100.000000
#             Andkhoy    50.000000    50.000000    50.000000      50.000000
#
# ...

# %% [markdown]
#  `df3.sort_index(level=0, ascending=False)` kodi `df3` DataFrame'ining indekslarini tartiblaydi.
# * `level=0`: Bu asosiy indeks darajasini, ya'ni **'Country' (davlat)** ustunini anglatadi.
# * `ascending=False`: Bu esa tartiblashni **kamayish tartibida** (ya'ni Z dan A ga qarab) amalga oshirishni bildiradi.

# %% [markdown]
# Agar biz `level=1` ni ishlatganimizda, indekslar **'City' (shahar)** ustuni bo'yicha tartiblanardi.

# %%
df3.sort_index(level=1, ascending=False)
# level=1 bilan City ustunini teskari alifbe tartibida joylashtirayabdi
# Out:
# Object                                     AIR                     WATER  \
# Info                                AirQuality AirPollution WaterQuality
# Country                    City
# Poland                     Zywiec    50.000000    50.000000    50.000000
# Germany                    Zwickau   75.000000    50.000000    25.000000
# Slovakia                   Zvolen    87.500000    50.000000    12.500000
# Switzerland                Zurich    83.809524    10.714286    16.190476
# People's Republic of China Zunyi      0.000000    50.000000   100.000000
# ...                                        ...          ...          ...
# Nigeria                    Aba        0.000000    50.000000   100.000000
# Belgium                    Aarschot  75.000000    41.666667    25.000000
# Switzerland                Aarau     87.500000     0.000000    12.500000
# Germany                    Aalen     87.500000    50.000000    12.500000
# ...

# %%
df3.sort_index(level=1, ascending=True)
# ascending=True bilan City ustunini alfbe tartibida joylashtiradi
# Out:
# Object                                     AIR                     WATER  \
# Info                                AirQuality AirPollution WaterQuality
# Country                    City
# Germany                    Aachen    70.454545    17.857143    29.545455
#                            Aalen     87.500000    50.000000    12.500000
# Switzerland                Aarau     87.500000     0.000000    12.500000
# Belgium                    Aarschot  75.000000    41.666667    25.000000
# Nigeria                    Aba        0.000000    50.000000   100.000000
# ...                                        ...          ...          ...
# People's Republic of China Zunyi      0.000000    50.000000   100.000000
# Switzerland                Zurich    83.809524    10.714286    16.190476
# Slovakia                   Zvolen    87.500000    50.000000    12.500000
# Germany                    Zwickau   75.000000    50.000000    25.000000
# ...
