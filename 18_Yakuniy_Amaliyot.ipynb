# %% [markdown]
# <a href="https://colab.research.google.com/github/sherjahong1r/my-data-sayns-lessons/blob/main/18_Yakuniy_Amaliyot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Imgur](https://i.imgur.com/h4PPC71.png)
# #**13-modul. Vizualizatsiya**
# #13.27. Modul boʻyicha yakuniy amaliy vazifa
#
# **Quyidagi vazifalarni bajarish orqali Matplotlib va Seaborn yordamida maʼlumotlarni vizualizatsiya qilish, diagrammalar yaratish, maʼlumotlar orasidagi bogʻliqlikni tahlil qilish koʻnikmalariga ega boʻlasiz.**

# %% [markdown]
# #Dataset bilan qisqacha tanishuv
#
# Quyida berilgan dataset World Happiness Report – global baxt holatining muhim tadqiqotidir. Birlashgan Millatlar Tashkilotida 20-mart – “Xalqaro Baxt kuni” munosabati bilan o‘tkazilgan tadbirda 155 ta davlatning baxtiyorlik darajasi bo‘yicha tuzilgan World Happiness 2017 reytingi e’lon qilindi. Hukumatlar, tashkilotlar va fuqarolik jamiyati oʻz siyosati, qarorlarini qabul qilishda baxtiyorlik koʻrsatkichlaridan tobora koʻproq foydalanmoqda. Shu sabab hisobot jahon miqyosida eʼtirof etilishda davom etmoqda. Iqtisodiyot, psixologiya, milliy statistika, sog‘liqni saqlash, davlat siyosati va boshqa sohalardagi yetakchi ekspertlar xalqlar taraqqiyotini baholashda farovonlik o‘lchovlaridan qanday samarali foydalanish mumkinligini tasvirlab beradi. Hisobotlar bugungi kunda dunyodagi baxtiyorlik darajasining holatini koʻrsatadi.
#
# ---
#
# ### **Ustunlar tavsifi**
#
# 1. **Country** – mamlakat nomi
#    - Bu satrda mamlakatlarning nomlari joylashgan.
#
# 2. **Happiness.Rank** – baxtlilik darajasi bo‘yicha reyting
#    - Har bir mamlakatning baxt darajasi bo‘yicha egallagan o‘rni.
#    - **1** – eng baxtli mamlakat, **so‘nggi o‘rin** – eng baxtsiz mamlakat.
#
# 3. **Happiness.Score** – baxtlilik darajasi
#    - Mamlakatning umumiy baxtlilik darajasi **(0–10 oralig‘ida)**.
#    - Bu baho turli omillarga asoslangan holda berilgan.
#
# 4. **Whisker.high** – yuqori ishonch oralig‘i (Upper Confidence Interval)
#    - **Happiness Score** qiymatining yuqori chegarasi (ishonchlilik darajasi bilan).
#
# 5. **Whisker.low** – pastki ishonch oralig‘i (Lower Confidence Interval)
#    - **Happiness Score** qiymatining pastki chegarasi.
#
# 6. **Economy..GDP.per.Capita.** – iqtisodiy farovonlik (YAIM)
#    - Aholi jon boshiga to‘g‘ri keladigan yalpi ichki mahsulot (YAIM).
#    - Mamlakat iqtisodining baxtlilik darajasiga ta’sirini ko‘rsatadi.
#
# 7. **Family** – jamiyatning qo‘llab-quvvatlashi
#    - Ijtimoiy aloqalar va oilaviy qo‘llab-quvvatlash darajasi.
#    - Ushbu qiymat qanchalik yuqori bo‘lsa, odamlar o‘zini shunchalik baxtli his qiladi.
#
# 8. **Health..Life.Expectancy.** – sog‘lom umr davomiyligi
#    - Odamlarning o‘rtacha qancha umr ko‘rishi va sog‘lom hayot kechirishi darajasi.
#    - Tibbiy xizmat sifati va hayot sharoitlari bilan bog‘liq.
#
# 9. **Freedom** – hayot tanlovlarida erkinlik
#    - Odamlarning o‘z hayotini erkin boshqarish darajasi.
#    - Mamlakatdagi demokratik va fuqarolik erkinliklarini aks ettiradi.
#
# 10. **Generosity** – saxiylik darajasi
#    - Jamiyatdagi saxiylik va xayriya qilishga moyillik darajasi.
#    - Ushbu qiymat qanchalik yuqori bo‘lsa, odamlar ko‘proq yordam berishga tayyor bo‘ladi.
#
# 11. **Trust..Government.Corruption.** – korrupsiya haqidagi tasavvurlar
#    - Mamlakatdagi korrupsiya darajasi bo‘yicha odamlarning fikri.
#    - **0 ga yaqin bo‘lsa**, odamlar davlatga ishonmaydi.
#    - **Yuqori qiymat bo‘lsa**, davlatga ishonch baland bo‘ladi.
#
# 12. **Dystopia.Residual** – baxtiyorlik darajasiga ta’sir etmaydigan omillar
#    - Ideal bo‘lmagan (Dystopia) sharoitlarda baxtlilik darajasini oshirishga yordam beruvchi faktorlar.
#    - Bu ko‘rsatkich mamlakat baxtlilik darajasi **modelining qoldiq qiymati** sifatida tushuniladi.
#
# ---
#
# **Qanday ishlatiladi?**
# - Ushbu ustunlar baxtlilik darajasiga turli faktorlarning ta’sirini o‘rganish uchun ishlatiladi.
# - **Matplotlib va Seaborn yordamida** ushbu omillarni vizualizatsiya qilish mumkin.
#
#
# ###*** ESLATMA**. *Ushbu amaliy vazifada siz oʻtmagan mavzulardan ham savollar va vazifalar boʻlishi mumkin! Bu savollarni mustaqil oʻrganishingiz kerak boʻladi. Bunday vazifalar mustaqil izlanish koʻnikmangizni oshirish uchun tayyorlandi!*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

url = "https://raw.githubusercontent.com/alishermutalov/praktikum-datasets/refs/heads/praktikum/happines_rank_2017.csv"
df = pd.read_csv(url)
df.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 0    0.362012                       0.315964           2.277027
# 1    0.355280                       0.400770           2.313707
# 2    0.475540                       0.153527           2.322715
# 3    0.290549                       0.367007           2.276716
# 4    0.245483                       0.382612           2.430182

# %%
df.shape
# Out:
# (155, 12)

# %% [markdown]
# #1) Baxtlilik darajasi va aholi jon boshiga to‘g‘ri keladigan YAIM o‘rtasidagi bog‘liqlikni scatterplot bilan vizualizatsiya qiling.

# %%
#javobni shu yerda yozing.
plt.figure(figsize=(15,8))
sns.scatterplot(data=df, x="Economy..GDP.per.Capita.", y="Happiness.Score", hue='Happiness.Rank', s=100)
plt.grid()
plt.show()

# %%
#Kutilgan natija quyidagicha:

# %% [markdown]
# #2) Baxtlilik darajasi (`Happiness.Score`) taqsimotini histogram orqali chizing.

# %%
#javobni shu yerda yozing.
sns.displot(data=df, x='Happiness.Score', height=5, aspect=2, kde=True)
plt.show()

# %%
#Kutilgan natija quyidagicha:

# %% [markdown]
# #3) Eng baxtli va eng baxtsiz 10 ta mamlakatni barplot orqali ko‘rsating.

# %%
max_10 = df.head(10)
sns.barplot(data=max_10, x='Happiness.Rank', y='Country',  palette='viridis')
# Out:
# /tmp/ipython-input-687231975.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=max_10, x='Happiness.Rank', y='Country',  palette='viridis')
# <Axes: xlabel='Happiness.Rank', ylabel='Country'>

# %%
min_10 = df.tail(10)
sns.barplot(data=min_10, x='Happiness.Rank', y='Country',  palette='viridis')
# Out:
# /tmp/ipython-input-1725532687.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=min_10, x='Happiness.Rank', y='Country',  palette='viridis')
# <Axes: xlabel='Happiness.Rank', ylabel='Country'>

# %%
#javobni shu yerda yozing.
import matplotlib.pyplot as plt
import seaborn as sns

fig, ax = plt.subplots(2, 1, figsize=(12, 10))

# Eng baxtli 10 ta mamlakat
top_10 = df.head(10)
sns.barplot(ax=ax[0], x='Happiness.Score', y='Country', data=top_10, palette='viridis')
ax[0].set_title('Eng baxtli 10 ta mamlakat (Happiness Score boʻyicha)')
ax[0].set_xlabel('Happiness Score')
ax[0].set_ylabel('Mamlakat')

# Eng baxtsiz 10 ta mamlakat
bottom_10 = df.tail(10)
sns.barplot(ax=ax[1], x='Happiness.Score', y='Country', data=bottom_10, palette='magma')
ax[1].set_title('Eng baxtsiz 10 ta mamlakat (Happiness Score boʻyicha)')
ax[1].set_xlabel('Happiness Score')
ax[1].set_ylabel('Mamlakat')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-537715542.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(ax=ax[0], x='Happiness.Score', y='Country', data=top_10, palette='viridis')
# /tmp/ipython-input-537715542.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(ax=ax[1], x='Happiness.Score', y='Country', data=bottom_10, palette='magma')

# %%
#javobni shu yerda yozing.
fig, ax = plt.subplots(2, 1, figsize=(10,10))
sns.barplot(ax=ax[0], data=max_10, x='Happiness.Rank', y='Country',  palette='viridis')
sns.barplot(ax=ax[1], data=min_10, x='Happiness.Rank', y='Country',  palette='viridis')
plt.show()
# Out:
# /tmp/ipython-input-3920073607.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(ax=ax[0], data=max_10, x='Happiness.Rank', y='Country',  palette='viridis')
# /tmp/ipython-input-3920073607.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(ax=ax[1], data=min_10, x='Happiness.Rank', y='Country',  palette='viridis')

# %%
#Kutilgan natija quyidagicha:

# %% [markdown]
# #4)  Baxtlilik darajasi (`Happiness.Score`) va ijtimoiy omillar (Freedom, Family Support, Generosity) bilan scatterplot (`subplot` orqali ketma ket) chizing!

# %%
df.head(1)
# Out:
#   Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0  Norway               1            7.537      7.594445     7.479556
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 0    0.362012                       0.315964           2.277027

# %%
#javobni shu yerda yozing.
fig, ax = plt.subplots(1,3, figsize=(15, 5))

sns.scatterplot(ax=ax[0], x='Freedom', y='Happiness.Score', hue='Happiness.Score', data=df, palette='viridis')
ax[1].set_title('Eng baxtsiz 10 ta mamlakat (Happiness Score boʻyicha)')
ax[0].set_ylabel('Happiness Score')
ax[0].set_xlabel('Freedom')

sns.scatterplot(ax=ax[1], x='Family',  y='Happiness.Score', hue='Happiness.Score', data=df, palette='magma')

sns.scatterplot(ax=ax[2], x='Generosity', y='Happiness.Score', hue='Happiness.Score', data=df, palette='magma')

plt.tight_layout()
plt.show()

# %%
#Kutilgan natija quyidagicha:

# %%
df.head(1)
# Out:
#   Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0  Norway               1            7.537      7.594445     7.479556
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 0    0.362012                       0.315964           2.277027

# %% [markdown]
# #5) Korrupsiya va baxtlilik darajasi bog‘liqligini koʻrsating!

# %%
df.head(1)
# Out:
#   Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0  Norway               1            7.537      7.594445     7.479556
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 0    0.362012                       0.315964           2.277027

# %%
#javobni shu yerda yozing.
plt.figure(figsize=(10,5))
plt.suptitle("Korrupsiya va baxtlilik darajasi bog‘liqligini")
sns.scatterplot(data=df, y="Happiness.Score", x="Trust..Government.Corruption.", hue="Happiness.Score", s=60)
plt.grid()
plt.show()

# %%
#Kutilgan natija quyidagicha:

# %% [markdown]
# #6) Baxtlilik darajasi va YAIM o‘rtasidagi bog‘liqlikni chiziqli regressiya orqali tekshiring!

# %%
#javobni shu yerda yozing.
plt.figure(figsize=(10,5))
plt.suptitle("Baxtlilik darajasi va YAIM o‘rtasidagi bog‘liqlik")
sns.scatterplot(data=df, y="Happiness.Score", x="Economy..GDP.per.Capita.", hue="Happiness.Score", s=60)
sns.regplot(data=df, x="Economy..GDP.per.Capita.", y="Happiness.Score")
plt.grid()
plt.show()

# %%
#Kutilgan natija quyidagicha:

# %% [markdown]
# #7) Issiqlik xaritasi (heatmap) orqali korrelyatsiyalarni ko‘rsating.

# %%
df.head(1)
# Out:
#   Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0  Norway               1            7.537      7.594445     7.479556
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 0    0.362012                       0.315964           2.277027

# %%
#javobni shu yerda yozing.
numeric_df = df.select_dtypes(include=[float, int])
# Faqat raqamli ustunlarni tanlab olamiz

plt.figure(figsize=(12,8))
sns.heatmap(data=numeric_df.corr(), cmap='viridis', linewidths=.5, annot=True, fmt=".2f")
# .corr()   barcha sonli ustunlar orasidagi korrelyatsiyani (bog'liqlikni) hisoblaydi.
# cmap='viridis'  rang turi
# linewidths=.5  kataklar orasidagi masofa
# annot=True Bu parametr True qilib belgilansa, har bir katakcha ichiga uning korrelyatsiya qiymati yozib qo'yiladi.
# fmt=".2f"   Bu parametr annot=True bilan birgalikda ishlatiladi. U annotatsiya matni uchun formatni belgilaydi.
#  ".2f" o'nlik kasrlarni ikki xona aniqlikda ko'rsatishni anglatadi (masalan, 0.75, 0.12, va hokazo).
plt.title('Ustunlar o\'rtasidagi korrelyatsiya issiqlik xaritasi')
plt.show()

# %%
#Kutilgan natija quyidagicha:

# %%
url = "https://raw.githubusercontent.com/alishermutalov/praktikum-datasets/refs/heads/praktikum/happines_rank_2017.csv"
df = pd.read_csv(url)
df.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 0    0.362012                       0.315964           2.277027
# 1    0.355280                       0.400770           2.313707
# 2    0.475540                       0.153527           2.322715
# 3    0.290549                       0.367007           2.276716
# 4    0.245483                       0.382612           2.430182

# %% [markdown]
# #8) 10 ta eng yuqori va eng past YAIMga ega mamlakatlarni barplot orqali aks ettiring!

# %%
#javobni shu yerda yozing.
# DataFrame'ni 'Economy..GDP.per.Capita.' bo'yicha o'sish tartibida saralash
df_sorted_gdp = df.sort_values(by='Economy..GDP.per.Capita.', ascending=True)

# Eng past 10 ta YAIMga ega mamlakatlarni tanlab olish
min_gdp_countries = df_sorted_gdp.head(10)

# Natijani ko'rsatish
display(min_gdp_countries)
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 154  Central African Republic             155            2.693      2.864884
# 92                    Somalia              93            5.151      5.242484
# 153                   Burundi             154            2.905      3.074690
# 125          Congo (Kinshasa)             126            4.280      4.357811
# 147                   Liberia             148            3.533      3.653756
# 134                     Niger             135            4.028      4.111947
# 135                    Malawi             136            3.970      4.077479
# 112                Mozambique             113            4.550      4.774102
# 148                    Guinea             149            3.507      3.584428
# 149                      Togo             150            3.495      3.594038
#
#      Whisker.low  Economy..GDP.per.Capita.    Family  \
# 154     2.521116                  0.000000  0.000000
# 92      5.059516                  0.022643  0.721151
# 153     2.735310                  0.091623  0.629794
# 125     4.202190                  0.092102  1.229023
# 147     3.412244                  0.119042  0.872118
# 134     3.944053                  0.161925  0.993025
# 135     3.862521                  0.233442  0.512569
# 112     4.325898                  0.234306  0.870701
# 148     3.429572                  0.244550  0.791245
# 149     3.395962                  0.305445  0.431883
#
#      Health..Life.Expectancy.   Freedom  Generosity  \
# 154                  0.018773  0.270842    0.280876
# 92                   0.113989  0.602127    0.291631
# 153                  0.151611  0.059901    0.204435
# 125                  0.191407  0.235961    0.246456
# 147                  0.229918  0.332881    0.266550
# 134                  0.268505  0.363659    0.228674
# 135                  0.315090  0.466915    0.287170
# 112                  0.106654  0.480791    0.322228
# 148                  0.194129  0.348588    0.264815
# 149                  0.247106  0.380426    0.196896
#
#      Trust..Government.Corruption.  Dystopia.Residual
# 154                       0.056565           2.066005
# 92                        0.282410           3.117485
# 153                       0.084148           1.683024
# 125                       0.060241           2.224959
# 147                       0.038948           1.673286
# 134                       0.138573           1.873983
# 135                       0.072712           2.081786
# 112                       0.179436           2.355651
# 148                       0.110938           1.552312
# 149                       0.095665           1.837229

# %%
# DataFrame'ni 'Economy..GDP.per.Capita.' bo'yicha o'sish tartibida saralash
df_sorted_gdp = df.sort_values(by='Economy..GDP.per.Capita.', ascending=False)

# Eng past 10 ta YAIMga ega mamlakatlarni tanlab olish
max_gdp_countries = df_sorted_gdp.head(10)

# %%
#javobni shu yerda yozing.
fig, ax = plt.subplots(1, 2, figsize=(12, 10))

top_10 = df.head(10)
sns.barplot(ax=ax[0], x='Economy..GDP.per.Capita.', y='Country', data=max_gdp_countries, palette='viridis')
ax[0].set_title('Eng baland YAIMga ega mamlakatlar')
ax[0].set_xlabel('YAIM')
ax[0].set_ylabel('Mamlakat')

bottom_10 = df.tail(10)
sns.barplot(ax=ax[1], x='Economy..GDP.per.Capita.', y='Country', data=min_gdp_countries, palette='magma')
ax[1].set_title('Eng past YAIMga ega mamlakatlar')
ax[1].set_xlabel('YAIM')
ax[1].set_ylabel('Mamlakat')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-1402914198.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(ax=ax[0], x='Economy..GDP.per.Capita.', y='Country', data=max_gdp_countries, palette='viridis')
# /tmp/ipython-input-1402914198.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(ax=ax[1], x='Economy..GDP.per.Capita.', y='Country', data=min_gdp_countries, palette='magma')

# %%
#Kutilgan natija quyidagicha:

# %% [markdown]
# #9) Oilaviy qo‘llab-quvvatlash va YAIM o‘rtasidagi bog‘liqlikni aks ettiring!

# %%
df.head(1)
# Out:
#   Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0  Norway               1            7.537      7.594445     7.479556
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 0    0.362012                       0.315964           2.277027

# %%
#javobni shu yerda yozing.
plt.figure(figsize=(10,5))
plt.suptitle("Oilaviy qo‘llab-quvvatlash va YAIM o‘rtasidagi bog‘liqlikni")
sns.scatterplot(data=df, y="Family", x="Economy..GDP.per.Capita.", s=60)

#ax[1].set_title('Eng baxtsiz 10 ta mamlakat (Happiness Score boʻyicha)')
plt.xlabel('Aholi jon boshiga YAIM')
plt.ylabel("Oilaviy qo'llab quvatlash")

plt.grid()
plt.show()

# %%
#Kutilgan natija quyidagicha:

# %% [markdown]
# # 10)  Saxiylik (Generosity) va hukumat korrupsiyasi (Trust..Government.Corruption.) o‘rtasidagi bog‘liqlikni scatterplot yordamida vizualizatsiya qiling!

# %%
#javobni shu yerda yozing.
plt.figure(figsize=(10,5))
plt.suptitle("Saxiylik va hukumat korrupsiyasi o‘rtasidagi bog‘liqlik (scatterplot yordamidagi vizualizatsiyasi) ")
sns.scatterplot(data=df, y="Trust..Government.Corruption.", x="Generosity", s=60)

#ax[1].set_title('Eng baxtsiz 10 ta mamlakat (Happiness Score boʻyicha)')
plt.xlabel('Sahiylik')
plt.ylabel("Hukumat Korrupsiyasi")

plt.grid()
plt.show()

# %%
#Kutilgan natija quyidagicha:

# %% [markdown]
# #11) Baxtlilik darajasi bo‘yicha mamlakatlarni “Juda baxtli”, “Baxtli”, “O‘rtacha”, “Baxtsiz” toifalariga ajrating va har bir guruh uchun o‘rtacha iqtisodiy ko‘rsatkichlarni (GDP per Capita) ko‘rsating.

# %%
df.head(1)
# Out:
#   Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0  Norway               1            7.537      7.594445     7.479556
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 0    0.362012                       0.315964           2.277027

# %%
df['Happiness.Score'].unique()
# Out:
# array([7.53700018, 7.52199984, 7.50400019, 7.49399996, 7.46899986,
#        7.37699986, 7.31599998, 7.31400013, 7.28399992, 7.21299982,
#        7.079     , 7.00600004, 6.99300003, 6.97700024, 6.95100021,
#        6.89099979, 6.86299992, 6.71400023, 6.65199995, 6.64799976,
#        6.63500023, 6.60900021, 6.59899998, 6.57800007, 6.57200003,
#        6.52699995, 6.454     , 6.45200014, 6.44199991, 6.42399979,
#        6.42199993, 6.40299988, 6.375     , 6.35699987, 6.34399986,
#        6.16800022, 6.10500002, 6.09800005, 6.08699989, 6.08400011,
#        6.0710001 , 6.0079999 , 6.00299978, 5.97300005, 5.97100019,
#        5.96400023, 5.96299982, 5.95599985, 5.92000008, 5.90199995,
#        5.87200022, 5.8499999 , 5.83799982, 5.82499981, 5.82299995,
#        5.82200003, 5.81899977, 5.80999994, 5.7579999 , 5.71500015,
#        5.62900019, 5.62099981, 5.61100006, 5.56899977, 5.5250001 ,
#        5.5       , 5.49300003, 5.47200012, 5.42999983, 5.39499998,
#        5.33599997, 5.32399988, 5.31099987, 5.29300022, 5.27899981,
#        5.27299976, 5.26900005, 5.26200008, 5.25      , 5.23699999,
#        5.23500013, 5.23400021, 5.23000002, 5.22700024, 5.2249999 ,
#        5.19500017, 5.18200016, 5.18100023, 5.17500019, 5.15100002,
#        5.07399988, 5.04099989, 5.01100016, 5.00400019, 4.96199989,
#        4.95499992, 4.829     , 4.80499983, 4.7750001 , 4.73500013,
#        4.71400023, 4.70900011, 4.69500017, 4.69199991, 4.64400005,
#        4.6079998 , 4.57399988, 4.55299997, 4.55000019, 4.54500008,
#        4.53499985, 4.51399994, 4.49700022, 4.46500015, 4.46000004,
#        4.44000006, 4.37599993, 4.31500006, 4.29199982, 4.29099989,
#        4.28599977, 4.28000021, 4.19000006, 4.17999983, 4.16800022,
#        4.13899994, 4.11999989, 4.09600019, 4.08099985, 4.03200006,
#        4.02799988, 3.97000003, 3.93600011, 3.875     , 3.80800009,
#        3.79500008, 3.79399991, 3.76600003, 3.65700006, 3.64400005,
#        3.60299993, 3.59299994, 3.59100008, 3.53299999, 3.50699997,
#        3.49499989, 3.47099996, 3.46199989, 3.34899998, 2.90499997,
#        2.69300008])

# %%
oraliq = [0, 3.5, 5.0, 6.5, 10]
toifalar = ['Baxtsiz', 'O‘rtacha', 'Baxtli', 'Juda baxtli']
df['Bahtlilik_darajasi'] = pd.cut(df['Happiness.Score'], bins=oraliq, labels=toifalar, right=False)
df.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual  \
# 0    0.362012                       0.315964           2.277027
# 1    0.355280                       0.400770           2.313707
# 2    0.475540                       0.153527           2.322715
# 3    0.290549                       0.367007           2.276716
# 4    0.245483                       0.382612           2.430182
#
#   Bahtlilik_darajasi
# 0        Juda baxtli
# 1        Juda baxtli
# 2        Juda baxtli
# 3        Juda baxtli
# 4        Juda baxtli

# %%
umumiy = df.groupby('Bahtlilik_darajasi')['Economy..GDP.per.Capita.'].mean().reindex(['Baxtsiz', 'O‘rtacha', 'Baxtli', 'Juda baxtli'])

plt.figure(figsize=(10, 6))
sns.barplot(x=umumiy.index, y=umumiy.values, palette='viridis')
plt.title('Har bir baxtlilik toifasi uchun o‘rtacha YAIM (GDP per Capita)')
plt.xlabel('Baxtlilik toifasi')
plt.ylabel('O‘rtacha YAIM (GDP per Capita)')
plt.grid(axis='y')
plt.show()
# Out:
# /tmp/ipython-input-2267715996.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   umumiy = df.groupby('Bahtlilik_darajasi')['Economy..GDP.per.Capita.'].mean().reindex(['Baxtsiz', 'O‘rtacha', 'Baxtli', 'Juda baxtli'])
# /tmp/ipython-input-2267715996.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=umumiy.index, y=umumiy.values, palette='viridis')

# %%
#Kutilgan natija quyidagicha:

# %% [markdown]
# #12) Muhim o‘zgaruvchilar (GDP, Life Expectancy, Freedom, Generosity, Happiness Score) bo‘yicha pairplot orqali umumiy taqsimotni vizualizatsiya qiling.

# %%
#javobni shu yerda yozing.
import seaborn as sns
import matplotlib.pyplot as plt

# Muhim o'zgaruvchilarni tanlab olish
important_vars = [
    'Economy..GDP.per.Capita.',
    'Health..Life.Expectancy.',
    'Freedom',
    'Generosity',
    'Happiness.Score'
]
df_subset = df[important_vars]

# Pairplot yaratish
sns.pairplot(df_subset, hue='Happiness.Score', palette='viridis', diag_kind='kde')
plt.suptitle('Muhim o‘zgaruvchilarning o‘zaro bog‘liqligi va taqsimoti (Pairplot)', y=1.02) # Sarlavhani joylashtirish
plt.show()

# important_vars = [...]: Bu ro'yxat pairplot uchun muhim deb topilgan ustun nomlarini o'z ichiga oladi.
# Bular: Economy..GDP.per.Capita., Health..Life.Expectancy., Freedom, Generosity, Happiness.Score.

# df_subset = df[important_vars]: Asl df DataFrame'idan faqat important_vars ro'yxatida
# ko'rsatilgan ustunlarni tanlab olib, df_subset nomli yangi DataFrame yaratadi.
# pairplot faqat shu tanlangan ustunlar bilan ishlaydi.

# sns.pairplot(): Bu seaborn funksiyasi DataFrame'dagi har bir o'zgaruvchi juftligi
# o'rtasidagi bog'liqlikni va har bir o'zgaruvchining o'z taqsimotini ko'rsatuvchi matritsali grafik (pairplot) yaratadi.
# data=df_subset: Grafikni chizish uchun df_subset ma'lumotlaridan foydalanishni belgilaydi.
