# %% [markdown]
# <a href="https://colab.research.google.com/github/sherjahong1r/my-data-sayns-lessons/blob/main/Google_colap_amaliyot_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# import uchun

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# # New Section

# %%
b = 2
a = 3
print(b + a)
# Out:
# 5

# %% [markdown]
# load **uchun**

# %%
def salom_ber():
    print("Salom!")

salom_ber()
# Out:
# Salom!
