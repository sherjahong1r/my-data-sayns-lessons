# %% [markdown]
# <a href="https://colab.research.google.com/github/sherjahong1r/my-data-sayns-lessons/blob/main/02_Fayldan_o'qish.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Fayldan o'qish**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **pandas kutubxonasi fayllar bilan ishlaydigan bir nechta funksiyalardan iborat.**
#
# read_csv - vergul bilan ajratilgan jadval fayylarni o'qish uchun.
#
# read_table - probel(bo'sh joy) bilan ajratilgan jadval fayllarni o'qish uchun.
#
# read_exel - xls yoki xlsx formatdagi Exel fayllarni o'qish uchun.
#
# read_clipboard - ko'chirilgan (xotiradagi) jadvalni o'qish.
#
# read_hdf - HDF5 formatdagi fayllarni o'qish.
#
# read_html - HTML (web) sahifadagi barcha jadvallarni o'qish.
#
# read_json - JSON ma'lumotlarni o'qish.
#
# read_pickle - pickle formatdagi fayllarni o'qish.
#
# read_sql - SQL query dan qaytgan ma'lumotlarni o'qish(SQLAlchemy bilan ishlaydi).

# %%
# Agar csv malumot shu yerdagi faylda saqlangan bo'lsa shunchaki nomini yozish ham kifoya agar fayilimiz papka ichida bo'lsa
# ( papka/file ) deb kiramiz yoki pastdagidek manzilini berish kerak
df = pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/merc.csv")
df.head()
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0        SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1    S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2   SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3    G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4    G Class  2016  73948    Automatic     4000   Petrol  325  30.1
#
#    engineSize
# 0         1.8
# 1         2.1
# 2         5.5
# 3         4.0
# 4         4.0

# %%
#pd.read_excel("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/uzbekistan.csv")
df = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/uzbekistan.csv')
df   # pandas avtomatiskiy index berib ketadi jadvalda indexsi bo'lmasa ham
# Out:
#                        Boʻlinishi  Maydoni (kv.km)    Aholisi
# 0                Andijon viloyati           4200.0  1899000.0
# 1                 Buxoro viloyati          39400.0  1384700.0
# 2               Fargʻona viloyati           6800.0  2597000.0
# 3                 Jizzax viloyati          20500.0   910500.0
# 4                 Xorazm viloyati           6300.0  1200000.0
# 5               Namangan viloyati           7900.0  1862000.0
# 6                 Navoiy viloyati         110800.0   767500.0
# 7            Qashqadaryo viloyati          28400.0  2029000.0
# 8   Qoraqalpogʻiston Respublikasi         160000.0  1200000.0
# 9              Samarqand viloyati          16400.0  2322000.0
# 10              Sirdaryo viloyati           5100.0   648100.0
# 11           Surxondaryo viloyati          20800.0  1676000.0
# 12              Toshkent viloyati          15300.0  4450000.0

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/uzbekistan.csv', index_col=0)
df1  # Bu yerda index_col=0 bilan viloyatlarni index qilib ketyabmiz
# Out:
#                                Maydoni (kv.km)    Aholisi
# Boʻlinishi
# Andijon viloyati                        4200.0  1899000.0
# Buxoro viloyati                        39400.0  1384700.0
# Fargʻona viloyati                       6800.0  2597000.0
# Jizzax viloyati                        20500.0   910500.0
# Xorazm viloyati                         6300.0  1200000.0
# Namangan viloyati                       7900.0  1862000.0
# Navoiy viloyati                       110800.0   767500.0
# Qashqadaryo viloyati                   28400.0  2029000.0
# Qoraqalpogʻiston Respublikasi         160000.0  1200000.0
# Samarqand viloyati                     16400.0  2322000.0
# Sirdaryo viloyati                       5100.0   648100.0
# Surxondaryo viloyati                   20800.0  1676000.0
# Toshkent viloyati                      15300.0  4450000.0

# %%
df2 = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/uzbekistan.csv', index_col=0, names=['hudud','maydon','aholi'])
df2 # names= bilan ustunlar nomini o'zgartirdik
# Out:
#                                         maydon       aholi
# hudud
# Boʻlinishi                     Maydoni (kv.km)     Aholisi
# Andijon viloyati                       4200.00  1899000.00
# Buxoro viloyati                       39400.00  1384700.00
# Fargʻona viloyati                      6800.00  2597000.00
# Jizzax viloyati                       20500.00   910500.00
# Xorazm viloyati                        6300.00  1200000.00
# Namangan viloyati                      7900.00  1862000.00
# Navoiy viloyati                      110800.00   767500.00
# Qashqadaryo viloyati                  28400.00  2029000.00
# Qoraqalpogʻiston Respublikasi        160000.00  1200000.00
# Samarqand viloyati                    16400.00  2322000.00
# Sirdaryo viloyati                      5100.00   648100.00
# Surxondaryo viloyati                  20800.00  1676000.00
# Toshkent viloyati                     15300.00  4450000.00

# %%
# Bazida shunday ro'yxatlar bo'ladi ular , or ; bilan bir-biridan ajratilgan bo'ladi, shunday holatlarda read_csv ga
# ular ; bunday ajratilganini ko'rsatib chiqarish uchun sep=";" buyrug'ini beramiz, va to'g'ri chiqarib beradi
# sep=";"
pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/merc.csv", index_col='model', nrows=14)
# index_col bilan model ustuni index o'rniga qo'yildi
# nrows=14 bilan boshidagi faqat 14 qator chiqariladi
# Out:
#            year   price transmission  mileage fuelType  tax   mpg  engineSize
# model
# SLK        2005    5200    Automatic    63000   Petrol  325  32.1         1.8
# S Class    2017   34948    Automatic    27000   Hybrid   20  61.4         2.1
# SL CLASS   2016   49948    Automatic     6200   Petrol  555  28.0         5.5
# G Class    2016   61948    Automatic    16000   Petrol  325  30.4         4.0
# G Class    2016   73948    Automatic     4000   Petrol  325  30.1         4.0
# SL CLASS   2011  149948    Automatic     3000   Petrol  570  21.4         6.2
# GLE Class  2018   30948    Automatic    16000   Diesel  145  47.9         2.1
# S Class    2012   10948    Automatic   107000   Petrol  265  36.7         3.5
# G Class    2019  139948    Automatic    12000   Petrol  145  21.4         4.0
# GLA Class  2017   19750    Automatic    15258   Diesel   30  64.2         2.1
# A Class    2020   32980    Automatic      606   Petrol  145  35.8         2.0
# ...
