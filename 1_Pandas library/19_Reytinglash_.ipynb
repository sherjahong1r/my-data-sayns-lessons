# %% [markdown]
# <a href="https://colab.research.google.com/github/sherjahong1r/my-data-sayns-lessons/blob/main/19_Reytinglash.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **REYTINGLASH**

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/usa_cars.csv', index_col=0)
df
# Out:
#       price      brand    model  year   title_status  mileage   color  \
# 0      6300     toyota  cruiser  2008  clean vehicle   274117   black
# 1      2899       ford       se  2011  clean vehicle   190552  silver
# 2      5350      dodge      mpv  2018  clean vehicle    39590  silver
# 3     25000       ford     door  2014  clean vehicle    64146    blue
# 4     27700  chevrolet     1500  2018  clean vehicle     6654     red
# ...     ...        ...      ...   ...            ...      ...     ...
# 2494   7800     nissan    versa  2019  clean vehicle    23609     red
# 2495   9200     nissan    versa  2018  clean vehicle    34553  silver
# 2496   9200     nissan    versa  2018  clean vehicle    31594  silver
# 2497   9200     nissan    versa  2018  clean vehicle    32557   black
# 2498   9200     nissan    versa  2018  clean vehicle    31371  silver
#
#                       vin        lot       state country      condition
# ...

# %%
df['rating'] = df['year'].rank() # Bunda reting degan yangi ustun ochildi

# %%
df # qaysida mashina kam bo'lsa shuning reytingi baland bo'ladi
# Out:
#       price      brand    model  year   title_status  mileage   color  \
# 0      6300     toyota  cruiser  2008  clean vehicle   274117   black
# 1      2899       ford       se  2011  clean vehicle   190552  silver
# 2      5350      dodge      mpv  2018  clean vehicle    39590  silver
# 3     25000       ford     door  2014  clean vehicle    64146    blue
# 4     27700  chevrolet     1500  2018  clean vehicle     6654     red
# ...     ...        ...      ...   ...            ...      ...     ...
# 2494   7800     nissan    versa  2019  clean vehicle    23609     red
# 2495   9200     nissan    versa  2018  clean vehicle    34553  silver
# 2496   9200     nissan    versa  2018  clean vehicle    31594  silver
# 2497   9200     nissan    versa  2018  clean vehicle    32557   black
# 2498   9200     nissan    versa  2018  clean vehicle    31371  silver
#
#                       vin        lot       state country      condition  \
# ...

# %%
df.sort_values('year') # Bunda ham 1973 yilda kam mashina bo'lgani uchun reytingda baland bo'lib turibdi yani 1 da.
# Out:
#       price      brand    model  year       title_status  mileage       color  \
# 32    29800  chevrolet   camaro  1973      clean vehicle    46226         red
# 405      25       ford     door  1984  salvage insurance    41577       white
# 545       0        gmc     door  1993  salvage insurance        0  light blue
# 322       0       ford  chassis  1994  salvage insurance        0       green
# 362      25       ford   pickup  1994  salvage insurance   206162       white
# ...     ...        ...      ...   ...                ...      ...         ...
# 1676  23400       ford   fusion  2020      clean vehicle     2452        gray
# 1642  20600       ford   fusion  2020      clean vehicle    17858       black
# 206      25  chevrolet   vehicl  2020  salvage insurance     7232       black
# 1640  27000       ford  mustang  2020      clean vehicle    12748         red
# 1638  20000       ford   fusion  2020      clean vehicle    23984      silver
#
# ...

# %%
df['rating'] = df['year'].rank()

# %%
df
# Out:
#       price      brand    model  year   title_status  mileage   color  \
# 0      6300     toyota  cruiser  2008  clean vehicle   274117   black
# 1      2899       ford       se  2011  clean vehicle   190552  silver
# 2      5350      dodge      mpv  2018  clean vehicle    39590  silver
# 3     25000       ford     door  2014  clean vehicle    64146    blue
# 4     27700  chevrolet     1500  2018  clean vehicle     6654     red
# ...     ...        ...      ...   ...            ...      ...     ...
# 2494   7800     nissan    versa  2019  clean vehicle    23609     red
# 2495   9200     nissan    versa  2018  clean vehicle    34553  silver
# 2496   9200     nissan    versa  2018  clean vehicle    31594  silver
# 2497   9200     nissan    versa  2018  clean vehicle    32557   black
# 2498   9200     nissan    versa  2018  clean vehicle    31371  silver
#
#                       vin        lot       state country      condition  \
# ...

# %%
df['rating'] = df['price'].rank(method='min') # Bunda mashina narxi qancha past bo'lsa 1 o'rinda turadi, aksincha qimmat bo'lsa oxirgi o'rinlarda turadi
df.sort_values('price')
# Out:
#       price          brand       model  year       title_status  mileage  \
# 455       0      chevrolet        door  2006  salvage insurance   268040
# 421       0            bmw        door  2000  salvage insurance   216657
# 420       0           audi        door  2005  salvage insurance   181896
# 419       0            kia       wagon  2008  salvage insurance   148463
# 293       0      chevrolet      pickup  1998  salvage insurance   258631
# ...     ...            ...         ...   ...                ...      ...
# 1215  65500           ford         srw  2019      clean vehicle     6500
# 277   67000          dodge  challenger  2019      clean vehicle    10944
# 1336  70000           ford         drw  2019      clean vehicle     9643
# 1340  74000           ford         drw  2019      clean vehicle    10536
# 502   84900  mercedes-benz    sl-class  2017      clean vehicle    25302
#
#          color                  vin        lot       state country  \
# ...

# %%
df['rating'] = df['mileage'].rank(method='average') # mileage yani qancha yurganini ko'rsatdi, agr kam yurgan bo'lsa reytingi baland bo'ladi

# %%
df.sort_values('mileage')
# Out:
#       price      brand    model  year       title_status  mileage       color  \
# 545       0        gmc     door  1993  salvage insurance        0  light blue
# 1236   4200       ford     door  2013      clean vehicle        0    no_color
# 309       0  chevrolet     door  2004  salvage insurance        0      maroon
# 322       0       ford  chassis  1994  salvage insurance        0       green
# 504     100  peterbilt    truck  2012  salvage insurance        0        blue
# ...     ...        ...      ...   ...                ...      ...         ...
# 531    2000  chevrolet   pickup  2003      clean vehicle   507985         red
# 490     475  peterbilt    truck  2012  salvage insurance   902041        gold
# 516       0  peterbilt    truck  2009  salvage insurance   982486        blue
# 1827   3200       ford     door  2013      clean vehicle   999999      silver
# 528    1025  peterbilt    truck  2010  salvage insurance  1017936      color:
#
# ...

# %%
df['rating'] = df['year'].rank(method='dense')

# %%
df
# Out:
#       price      brand    model  year   title_status  mileage   color  \
# 0      6300     toyota  cruiser  2008  clean vehicle   274117   black
# 1      2899       ford       se  2011  clean vehicle   190552  silver
# 2      5350      dodge      mpv  2018  clean vehicle    39590  silver
# 3     25000       ford     door  2014  clean vehicle    64146    blue
# 4     27700  chevrolet     1500  2018  clean vehicle     6654     red
# ...     ...        ...      ...   ...            ...      ...     ...
# 2494   7800     nissan    versa  2019  clean vehicle    23609     red
# 2495   9200     nissan    versa  2018  clean vehicle    34553  silver
# 2496   9200     nissan    versa  2018  clean vehicle    31594  silver
# 2497   9200     nissan    versa  2018  clean vehicle    32557   black
# 2498   9200     nissan    versa  2018  clean vehicle    31371  silver
#
#                       vin        lot       state country      condition  \
# ...

# %%
df.sort_values(by='year', ascending=False)
# Out:
#       price      brand     model  year       title_status  mileage  \
# 2306  19000     nissan     cargo  2020      clean vehicle      264
# 2305  14700     nissan     rogue  2020      clean vehicle    15387
# 2302  21100     nissan     rogue  2020      clean vehicle    19597
# 657   22000  chevrolet      trax  2020      clean vehicle      179
# 1217  32500       ford  explorer  2020      clean vehicle     5920
# ...     ...        ...       ...   ...                ...      ...
# 322       0       ford   chassis  1994  salvage insurance        0
# 362      25       ford    pickup  1994  salvage insurance   206162
# 545       0        gmc      door  1993  salvage insurance        0
# 405      25       ford      door  1984  salvage insurance    41577
# 32    29800  chevrolet    camaro  1973      clean vehicle    46226
#
#            color                  vin        lot           state country  \
# 2306       black    3n6cm0kn9lk693851  167129224      california     usa
# ...

# %%
df.sort_values(by=['price','mileage'], ascending=False)
# Out:
#       price          brand       model  year       title_status  mileage  \
# 502   84900  mercedes-benz    sl-class  2017      clean vehicle    25302
# 1340  74000           ford         drw  2019      clean vehicle    10536
# 1336  70000           ford         drw  2019      clean vehicle     9643
# 277   67000          dodge  challenger  2019      clean vehicle    10944
# 1215  65500           ford         srw  2019      clean vehicle     6500
# ...     ...            ...         ...   ...                ...      ...
# 196       0           ford         mpv  2017      clean vehicle    76858
# 349       0      heartland    sundance  2009      clean vehicle        1
# 309       0      chevrolet        door  2004  salvage insurance        0
# 322       0           ford     chassis  1994  salvage insurance        0
# 545       0            gmc        door  1993  salvage insurance        0
#
#            color                  vin        lot         state country  \
# ...

# %%
df.sort_values(by='price', ascending=False)
# Out:
#       price          brand       model  year       title_status  mileage  \
# 502   84900  mercedes-benz    sl-class  2017      clean vehicle    25302
# 1340  74000           ford         drw  2019      clean vehicle    10536
# 1336  70000           ford         drw  2019      clean vehicle     9643
# 277   67000          dodge  challenger  2019      clean vehicle    10944
# 1215  65500           ford         srw  2019      clean vehicle     6500
# ...     ...            ...         ...   ...                ...      ...
# 318       0      chevrolet        door  2009  salvage insurance   117059
# 305       0           ford        door  2003  salvage insurance   246065
# 510       0           ford        door  2010  salvage insurance    86841
# 522       0           ford        door  2008  salvage insurance   145483
# 144       0          dodge        door  2014  salvage insurance   123660
#
#          color                  vin        lot     state country  \
# ...
