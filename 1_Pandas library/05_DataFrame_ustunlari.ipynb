# %% [markdown]
# <a href="https://colab.research.google.com/github/sherjahong1r/my-data-sayns-lessons/blob/main/5_DataFrame_ustunlari.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## DataFrame ma'lumotlar tuzilmasi

# %%
import pandas as pd

# %%
data = {
    'Yil':[2025, 2024, 2023, 2022, 2021, 2020, 2019, 2018],
    'Aholi soni':[36.5, 35.8, 35.2, 34.9, 34.1, 33.8, 33.0, 32.3],
    'Temp':[1.54, 1.48, 1.56, 1.62, 1.60, 1.59, 1.61, 1.57]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#     Yil  Aholi soni  Temp
# 0  2025        36.5  1.54
# 1  2024        35.8  1.48
# 2  2023        35.2  1.56
# 3  2022        34.9  1.62
# 4  2021        34.1  1.60
# 5  2020        33.8  1.59
# 6  2019        33.0  1.61
# 7  2018        32.3  1.57

# %%
df.head()
# Out:
#     Yil  Aholi soni  Temp
# 0  2025        36.5  1.54
# 1  2024        35.8  1.48
# 2  2023        35.2  1.56
# 3  2022        34.9  1.62
# 4  2021        34.1  1.60

# %%
df.shape
# Out:
# (8, 3)

# %%
df = pd.DataFrame(data, columns=['Yil', 'Temp', 'Aholi soni']) # Bunda temp va Aholi sonini joyini almashtirdik.

# %%
df.head()
# Out:
#     Yil  Temp  Aholi soni
# 0  2025  1.54        36.5
# 1  2024  1.48        35.8
# 2  2023  1.56        35.2
# 3  2022  1.62        34.9
# 4  2021  1.60        34.1

# %%
df = pd.DataFrame(data, columns=['Yil', 'Temp', 'Aholi soni', 'YAIM']) # YAIM qiymati mavjud bo'lmagani uchun non deb chiqadi

# %%
df
# Out:
#     Yil  Temp  Aholi soni YAIM
# 0  2025  1.54        36.5  NaN
# 1  2024  1.48        35.8  NaN
# 2  2023  1.56        35.2  NaN
# 3  2022  1.62        34.9  NaN
# 4  2021  1.60        34.1  NaN
# 5  2020  1.59        33.8  NaN
# 6  2019  1.61        33.0  NaN
# 7  2018  1.57        32.3  NaN

# %%
df = pd.DataFrame(data, columns=['Yil', 'Temp', 'Aholi soni', 'YAIM'], index=[25, 24, 23, 22, 21, 20, 19, 18]) # Hamda matnli index kiritsak ham bo'ladi bir, ikki deb.

# %%
df
# Out:
#      Yil  Temp  Aholi soni YAIM
# 25  2025  1.54        36.5  NaN
# 24  2024  1.48        35.8  NaN
# 23  2023  1.56        35.2  NaN
# 22  2022  1.62        34.9  NaN
# 21  2021  1.60        34.1  NaN
# 20  2020  1.59        33.8  NaN
# 19  2019  1.61        33.0  NaN
# 18  2018  1.57        32.3  NaN

# %%
aholi = df['Aholi soni']

# %%
aholi
# Out:
# 25    36.5
# 24    35.8
# 23    35.2
# 22    34.9
# 21    34.1
# 20    33.8
# 19    33.0
# 18    32.3
# Name: Aholi soni, dtype: float64

# %%
type(aholi) # Bunda pandas.core.series.Series deb chiqadi.

# %%
df.Temp
# Out:
# 25    1.54
# 24    1.48
# 23    1.56
# 22    1.62
# 21    1.60
# 20    1.59
# 19    1.61
# 18    1.57
# Name: Temp, dtype: float64

# %%
df
# Out:
#      Yil  Temp  Aholi soni YAIM
# 25  2025  1.54        36.5  NaN
# 24  2024  1.48        35.8  NaN
# 23  2023  1.56        35.2  NaN
# 22  2022  1.62        34.9  NaN
# 21  2021  1.60        34.1  NaN
# 20  2020  1.59        33.8  NaN
# 19  2019  1.61        33.0  NaN
# 18  2018  1.57        32.3  NaN

# %%
df.YAIM = 0

# %%
df
# Out:
#      Yil  Temp  Aholi soni  YAIM
# 25  2025  1.54        36.5     0
# 24  2024  1.48        35.8     0
# 23  2023  1.56        35.2     0
# 22  2022  1.62        34.9     0
# 21  2021  1.60        34.1     0
# 20  2020  1.59        33.8     0
# 19  2019  1.61        33.0     0
# 18  2018  1.57        32.3     0

# %%
val = pd.Series([1700, 1650, 1300], index=[25, 23, 20])

# %%
df.YAIM = val

# %%
df
# Out:
#      Yil  Temp  Aholi soni    YAIM
# 25  2025  1.54        36.5  1700.0
# 24  2024  1.48        35.8     NaN
# 23  2023  1.56        35.2  1650.0
# 22  2022  1.62        34.9     NaN
# 21  2021  1.60        34.1     NaN
# 20  2020  1.59        33.8  1300.0
# 19  2019  1.61        33.0     NaN
# 18  2018  1.57        32.3     NaN

# %%
val = [1700, 1637, 1233, 1887, 1233, 1213, 1490, 1300]
df.YAIM = val

# %%
df
# Out:
#      Yil  Temp  Aholi soni  YAIM
# 25  2025  1.54        36.5  1700
# 24  2024  1.48        35.8  1637
# 23  2023  1.56        35.2  1233
# 22  2022  1.62        34.9  1887
# 21  2021  1.60        34.1  1233
# 20  2020  1.59        33.8  1213
# 19  2019  1.61        33.0  1490
# 18  2018  1.57        32.3  1300

# %%
df['Normal+'] = df.YAIM>1300 # Yani 1300 dan katta bo'lasa True kichik bo'lsa False chiqaradi.

# %%
df
# Out:
#      Yil  Temp  Aholi soni  YAIM  Normal+
# 25  2025  1.54        36.5  1700     True
# 24  2024  1.48        35.8  1637     True
# 23  2023  1.56        35.2  1233    False
# 22  2022  1.62        34.9  1887     True
# 21  2021  1.60        34.1  1233    False
# 20  2020  1.59        33.8  1213    False
# 19  2019  1.61        33.0  1490     True
# 18  2018  1.57        32.3  1300    False

# %%
del df['Normal+'] # Bu bilan Normal+ ustunini o'chirib tashladik.

# %%
df
# Out:
#      Yil  Temp  Aholi soni  YAIM
# 25  2025  1.54        36.5  1700
# 24  2024  1.48        35.8  1637
# 23  2023  1.56        35.2  1233
# 22  2022  1.62        34.9  1887
# 21  2021  1.60        34.1  1233
# 20  2020  1.59        33.8  1213
# 19  2019  1.61        33.0  1490
# 18  2018  1.57        32.3  1300
