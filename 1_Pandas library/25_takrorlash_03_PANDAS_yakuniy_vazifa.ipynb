# %% [markdown]
# <a href="https://colab.research.google.com/github/sherjahong1r/my-data-sayns-lessons/blob/main/25_takrorlash_03_PANDAS_yakuniy_vazifa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Imgur](https://i.imgur.com/5pXzCIu.png)
#
# # Data Science va Sun'iy Intellekt Praktikum
#
# ## Ma'lumotlar tahlili. Pandas kutubxonasi.
#
# ### PANDAS. Yakuniy vazifa. **1-QISM**

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/world_population.csv", index_col=0)

# %% [markdown]
# ### 1-VAZIFA. Yuqoridagi DF ustunlari nomini quyidagi qiymatlarga o'zgartiring va DF yuqorisidan 3 ta davlatni chiqaring
# `['davlat','zichlik_km','zichlik_mi','aholi','maydoni']`

# %%
# JAVOBNI SHUYERGA YOZING
print(f"Bu asl ro'yxat va pastdagilari o'zgargan \n\n{df}")
df.columns = ['davlat','zichlik_km','zichlik_mi','aholi','maydoni']
df.head(3)
# Out:
# Bu asl ro'yxat va pastdagilari o'zgargan
#
#                country     density   densityMi   pop2021     area
# rank
# 1                Macau  21946.4667  56841.3487   658.394       30
# 2               Monaco  19755.5000  51166.7450    39.511        2
# 3            Singapore   8305.1915  21510.4461  5896.686      710
# 4            Hong Kong   6841.3134  17719.0017  7552.810     1104
# 5            Gibraltar   5616.3333  14546.3033    33.698        6
# ...                ...         ...         ...       ...      ...
# 228            Namibia      3.1338      8.1166  2587.344   825615
# 229     Western Sahara      2.3003      5.9577   611.875   266000
# 230           Mongolia      2.1286      5.5129  3329.289  1564110
# 231   Falkland Islands      0.2902      0.7517     3.533    12173
# 232          Greenland      0.0263      0.0680    56.877  2166086
#
# [232 rows x 5 columns]
#          davlat  zichlik_km  zichlik_mi     aholi  maydoni
# rank
# 1         Macau  21946.4667  56841.3487   658.394       30
# 2        Monaco  19755.5000  51166.7450    39.511        2
# 3     Singapore   8305.1915  21510.4461  5896.686      710

# %%
#@title To'g'ri javob
df.columns = ['davlat','zichlik_km','zichlik_mi','aholi','maydoni']
df.head(3)
# Out:
#          davlat  zichlik_km  zichlik_mi     aholi  maydoni
# rank
# 1         Macau  21946.4667  56841.3487   658.394       30
# 2        Monaco  19755.5000  51166.7450    39.511        2
# 3     Singapore   8305.1915  21510.4461  5896.686      710

# %% [markdown]
# ## Yuqoridagi jadval dunyo davlatlarining aholi zichligi bo'yicha reytingini ko'rsatadi.
# DF indeksi sifatida davlatning zichlik reytingi olingan (aholi eng zich yashaydigan davlatlar yuqorida).
#
# **Ustunlar:**
#
# `davlat` - Davlat nomi
#
# `zichlik_km` - har 1 kv.km. ga to'g'ri keluvchi aholi soni
#
# `zichlik_mi` - har 1 kv.milyaga to'g'ri keluvchi aholi soni (milya - AQSh masofa o'lchov birligi)
#
# `aholi` - 2021-yilga ko'rsa aholi soni (ming)
#
# `maydoni` - davlat maydoni (kv.km)

# %% [markdown]
# ### 2-VAZIFA. DF oxiridan 10 ta qator chiqaring.

# %%
# JAVOBNI SHUYERGA YOZING
df.tail(10)
# Out:
#                 davlat  zichlik_km  zichlik_mi      aholi  maydoni
# rank
# 223             Guyana      3.6765      9.5220    790.326   214969
# 224      French Guiana      3.6685      9.5015    306.448    83534
# 225           Suriname      3.6125      9.3564    591.800   163820
# 226          Australia      3.3526      8.6832  25788.215  7692024
# 227            Iceland      3.3335      8.6338    343.353   103000
# 228            Namibia      3.1338      8.1166   2587.344   825615
# 229     Western Sahara      2.3003      5.9577    611.875   266000
# 230           Mongolia      2.1286      5.5129   3329.289  1564110
# 231   Falkland Islands      0.2902      0.7517      3.533    12173
# 232          Greenland      0.0263      0.0680     56.877  2166086

# %% [markdown]
# ### 3-VAZIFA. DF dan 10, 20, 100, 200-indekslarda turgan davlatlarni alohida DF ko'rinishida chiqaring.

# %%
# JAVOBNI SHUYERGA YOZING
result = [10, 20, 100, 200]
tr1 = df.loc[result]
print(tr1)
# Out:
#            davlat  zichlik_km  zichlik_mi     aholi  maydoni
# rank
# 10        Bermuda   1149.8148   2978.0204    62.090       54
# 20          Aruba    595.5778   1542.5464   107.204      180
# 100      Slovakia    111.3592    288.4203  5460.721    49037
# 200   New Zealand     17.9713     46.5457  4860.643   270467

# %% [markdown]
# ### 4-VAZIFA. Davlatlar orasida `Uzbekistan`, `Hong-Kong`, `Antartica` borligini tekshiring

# %%
# JAVOBNI SHUYERGA YOZING
countries = ["Uzbekistan", "Hong-Kong", "Antartica"]

df[df["davlat"].isin(countries)]
# Out:
#           davlat  zichlik_km  zichlik_mi      aholi  maydoni
# rank
# 133   Uzbekistan     75.8511    196.4542  33935.763   447400

# %% [markdown]
# ### 5-VAZIFA.
# #### 5.1 DFning `davlat` nomli ustunini uning indeksi qilib belgilang.
# #### 5.2 `davlat` ustunini tashlab yuboring.
# #### 5.3 DFni davlat nomi bo'yicha tartiblang

# %%
# JAVOBNI SHUYERGA YOZING

# %%
#@title Kutilayotgan natija
df = df.set_index("davlat").sort_index()
df # set_index() davlat ustunini indexga aylantiradi, sort_index() alifbe tartibida chiqaradi
# Out:
#                    zichlik_km  zichlik_mi      aholi  maydoni
# davlat
# Afghanistan           61.0757    158.1862  39835.428   652230
# Albania               99.9351    258.8318   2872.933    28748
# Algeria               18.7328     48.5179  44616.624  2381741
# American Samoa       276.8844    717.1307     55.100      199
# Andorra              165.2885    428.0971     77.355      468
# ...                       ...         ...        ...      ...
# Wallis and Futuna     78.1268    202.3483     11.094      142
# Western Sahara         2.3003      5.9577    611.875   266000
# Yemen                 57.7509    149.5749  30490.640   527968
# Zambia                25.1400     65.1125  18920.651   752612
# Zimbabwe              38.6229    100.0333  15092.171   390757
#
# [232 rows x 4 columns]

# %% [markdown]
# ### 6-VAZIFA. DF dan `Uzbekistan`, `Malaysia`, `South Korea`, `France` davlatlari `aholi` va `maydoni` ustunlari bilan alohida DF ko'rinishida ajratib oling.

# %%
# JAVOBNI SHUYERGA YOZING
davlatlar = ['Uzbekistan', 'Malaysia', 'South Korea', 'France']
df_6 = df.loc[davlatlar, ['aholi', 'maydoni']]
df_6
# Out:
#                  aholi  maydoni
# davlat
# Uzbekistan   33935.763   447400
# Malaysia     32776.194   330803
# South Korea  51305.186   100210
# France       65426.179   551695

# %%
#@title O'xshash natija (boshqa davlatlar uchun)
state = ['Afghanistan', 'Yemen', 'Zambia']
df_7 = df.loc[state, ['zichlik_mi', 'zichlik_km']]
df_7
# Out:
#              zichlik_mi  zichlik_km
# davlat
# Afghanistan    158.1862     61.0757
# Yemen          149.5749     57.7509
# Zambia          65.1125     25.1400

# %% [markdown]
# ### 7-VAZIFA. Asl DFning `aholi` ustuni qiymatlarini 1000 ga ko'paytiring.

# %%
# JAVOBNI SHUYERGA YOZING
dfa = df.aholi.multiply(1000)

# %%
#@title Kutilgan natija
dfa
# Out:
# davlat
# Afghanistan          39835428.0
# Albania               2872933.0
# Algeria              44616624.0
# American Samoa          55100.0
# Andorra                 77355.0
#                         ...
# Wallis and Futuna       11094.0
# Western Sahara         611875.0
# Yemen                30490640.0
# Zambia               18920651.0
# Zimbabwe             15092171.0
# Name: aholi, Length: 232, dtype: float64

# %% [markdown]
# DF ni `aholi` ustuni bo'yicha kamayish tartibida tahlang va aholisi eng kam 10 ta davlatni chiqaring.

# %%
# JAVOBNI SHUYERGA YOZING
df_sorted = df.sort_values(by='aholi', ascending=False)
df_sorted.tail(10)
# Out:
#                            zichlik_km  zichlik_mi   aholi  maydoni
# davlat
# Tuvalu                       458.8846   1188.5112  11.931       26
# Wallis and Futuna             78.1268    202.3483  11.094      142
# Nauru                        517.9048   1341.3733  10.876       21
# Saint Barthelemy             471.7619   1221.8633   9.907       21
# Saint Pierre and Miquelon     23.8264     61.7105   5.766      242
# Montserrat                    48.7941    126.3768   4.977      102
# Falkland Islands               0.2902      0.7517   3.533    12173
# Niue                           6.2269     16.1277   1.619      260
# Tokelau                      114.4167    296.3392   1.373       12
# Vatican City                 800.0000   2072.0000   0.800        1

# %% [markdown]
# ### 8-VAZIFA. DFni `maydoni` bo'yicha reytinglang (rank) va reytinglarni yangi `rank` ustuniga yozing.

# %%
# JAVOBNI SHUYERGA YOZING
df['rank'] = df['maydoni'].rank()
df.sort_values("maydoni")
# Out:
#                zichlik_km  zichlik_mi        aholi   maydoni   rank
# davlat
# Vatican City     800.0000   2072.0000        0.800         1    1.0
# Monaco         19755.5000  51166.7450       39.511         2    2.0
# Gibraltar       5616.3333  14546.3033       33.698         6    3.0
# Tokelau          114.4167    296.3392        1.373        12    4.0
# Nauru            517.9048   1341.3733       10.876        21    5.5
# ...                   ...         ...          ...       ...    ...
# Brazil            25.1291     65.0843   213993.437   8515767  228.0
# United States     35.5200     91.9968   332915.073   9372610  229.0
# China            148.7815    385.3441  1444216.107   9706961  230.0
# Canada             3.8126      9.8747    38067.903   9984670  231.0
# Russia             8.5337     22.1024   145912.025  17098242  232.0
#
# [232 rows x 5 columns]

# %%
#@title Kutilgan natija

# %% [markdown]
# #### `Uzbekistan`, `United Kingdom`, `Indonesia` davlatlari alohida df ko'rinishida chiqaring

# %%
# JAVOBNI SHUYERGA YOZING
df3 = ['Uzbekistan', 'United Kingdom', 'Indonesia']
df_new = df.loc[df3]
df_new
# Out:
#                 zichlik_km  zichlik_mi       aholi  maydoni   rank
# davlat
# Uzbekistan         75.8511    196.4542   33935.763   447400  176.0
# United Kingdom    280.8033    727.2805   68207.116   242900  153.0
# Indonesia         145.1046    375.8210  276361.783  1904569  218.0

# %%
#@title O'xshash natija (boshqa davlatlar uchun)

# %% [markdown]
# ### 9-VAZIFA. DFni `davlat` nomi bo'yicha tartiblang.

# %%
# JAVOBNI SHUYERGA YOZING
df_sorted = df.sort_values(by='davlat')

# %%
#@title Kutilgan natija
df_sorted
# Out:
#                    zichlik_km  zichlik_mi      aholi  maydoni   rank
# davlat
# Afghanistan           61.0757    158.1862  39835.428   652230  192.0
# Albania               99.9351    258.8318   2872.933    28748   89.0
# Algeria               18.7328     48.5179  44616.624  2381741  223.0
# American Samoa       276.8844    717.1307     55.100      199   20.0
# Andorra              165.2885    428.0971     77.355      468   38.0
# ...                       ...         ...        ...      ...    ...
# Wallis and Futuna     78.1268    202.3483     11.094      142   15.0
# Western Sahara         2.3003      5.9577    611.875   266000  155.0
# Yemen                 57.7509    149.5749  30490.640   527968  183.0
# Zambia                25.1400     65.1125  18920.651   752612  194.0
# Zimbabwe              38.6229    100.0333  15092.171   390757  172.0
#
# [232 rows x 5 columns]

# %% [markdown]
# #### DFdan 10,50,100,200-o'rinda turgan davlatlarni alohida DF ko'rinishida chiqaring

# %%
# JAVOBNI SHUYERGA YOZING
df_natija = df.iloc[[10, 50, 100, 200]]
df_natija
# Out:
#                 zichlik_km  zichlik_mi      aholi  maydoni   rank
# davlat
# Aruba             595.5778   1542.5464    107.204      180   18.0
# Czech Republic    135.9862    352.2044  10724.555    78865  115.0
# Jamaica           270.5362    700.6887   2973.463    10991   68.0
# Syria              98.6916    255.6111  18275.702   185180  144.0

# %%
#@title O'xshash natija (boshqa qatorlar uchun)
df_sorted = df.sort_values(by='davlat')
df_natija = df_sorted.iloc[[10, 50, 100, 200]]
df_natija
# Out:
#                 zichlik_km  zichlik_mi      aholi  maydoni   rank
# davlat
# Aruba             595.5778   1542.5464    107.204      180   18.0
# Czech Republic    135.9862    352.2044  10724.555    78865  115.0
# Jamaica           270.5362    700.6887   2973.463    10991   68.0
# Syria              98.6916    255.6111  18275.702   185180  144.0

# %% [markdown]
# ### 10-VAZIFA. Quyidagi davlatlarning `aholi` sonini oddiy son ko'rinishida chiqaring:
# - `Malaysia`
# - `Nigeria`
# - `Nepal`
# - `Italy`

# %%
# JAVOBNI SHUYERGA YOZING
davlatlar = ['Malaysia', 'Nigeria', 'Nepal', 'Italy']

df.loc[davlatlar, 'aholi'].astype(int)
# Out:
# davlat
# Malaysia     32776
# Nigeria     211400
# Nepal        29674
# Italy        60367
# Name: aholi, dtype: int64

# %%
#@title o'xshash natija (`Uzbekistan` uchun)
davlatlar = ['Uzbekistan']
df.loc[davlatlar, 'aholi'].astype(int)
# Out:
# davlat
# Uzbekistan    33935
# Name: aholi, dtype: int64
