# %% [markdown]
# <a href="https://colab.research.google.com/github/sherjahong1r/my-data-sayns-lessons/blob/main/09_Amaliy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Imgur](https://i.imgur.com/5pXzCIu.png)
#
# # Data Science va Sun'iy Intellekt Praktikum
#
# ## 4-MODUL. VIZUALIZASIYA
#
# ## 3-AMALIYOT. `scatterplot`

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Ushbu amaliyotda uybor.uz saytidan yuklab olingan ma'lumotlar tahlili bilan shu'gullanamiz.

# %%
df = pd.read_csv("https://github.com/anvarnarz/praktikum_datasets/blob/main/uybor_scrapping.csv?raw=true")
df.head()
# Out:
#                                             location       district  rooms  \
# 0  город Ташкент, Юнусабадский район, Юнусабад 8-...   Юнусабадский      3
# 1  город Ташкент, Яккасарайский район, 1-й тупик ...  Яккасарайский      2
# 2  город Ташкент, Чиланзарский район, Чиланзар 2-...   Чиланзарский      2
# 3  город Ташкент, Чиланзарский район, Чиланзар 9-...   Чиланзарский      3
# 4  город Ташкент, Чиланзарский район, площадь Актепа   Чиланзарский      3
#
#    size  level  max_levels  price        lat        lng
# 0  57.0      4           4  52000  41.371471  69.281049
# 1  52.0      4           5  56000  41.291115  69.261104
# 2  42.0      4           4  37000  41.280784  69.223683
# 3  65.0      1           4  49500  41.290163  69.196862
# 4  70.0      3           5  55000  41.300156  69.210831

# %%
df.shape
# Out:
# (7421, 9)

# %% [markdown]
# #### Yuqoridagi jadvalda Toshkent shahridagi sotildagian uylar haqida ma'lumotlar jamlangan.
#
# ### 1-VAZIFA. Uylarning narxi (`price`) va maydoni (`size`) o'rtasida bog'liqlikni ko'rsatuvchi scatter plot chizing.

# %%
#JAVOBINGIZNI SHUYERGA YOZING
plt.figure(figsize=(15,8))
sns.scatterplot(data=df, x="size", y="price", hue='price', s=100)
plt.show()

# %%
#@title Kutilgan natija
plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='size', y='price')
plt.show()

# %% [markdown]
# ### Jadvalda 7000 dan oshiq uy bor, aksar uylarning maydoni 250kv.m dan kam. Keling noodatiy katta qiymatlarni tashlab yuboramiz va yuqoridagi chizmani qaytadan chizamiz.

# %%
df.head(1)
# Out:
#                                             location      district  rooms  \
# 0  город Ташкент, Юнусабадский район, Юнусабад 8-...  Юнусабадский      3
#
#    size  level  max_levels  price        lat        lng
# 0  57.0      4           4  52000  41.371471  69.281049

# %%
df['size'].unique()
# Out:
# array([ 57.  ,  52.  ,  42.  ,  65.  ,  70.  ,  28.  ,  30.  ,  32.  ,
#         51.  ,  67.  ,  35.  ,  43.  ,  90.  ,  80.  ,  69.  ,  96.  ,
#         76.  ,  45.  ,  27.  ,  64.  ,  26.  ,  72.  , 100.  ,  63.  ,
#         48.  , 102.  ,  78.  ,  34.  ,  56.  ,  98.  ,  93.  ,  60.  ,
#         82.  , 120.  , 110.  ,  95.  ,  68.  ,  46.  ,  40.  ,  53.  ,
#         54.  ,  20.  ,  50.  ,  36.  ,  58.  ,  74.  ,  94.  ,  85.  ,
#        125.  ,  64.67,  22.  ,  66.  ,  37.  ,  61.  ,  69.65,  88.  ,
#         38.  ,  55.13,  91.  , 111.  , 107.  ,  62.  ,  40.41,  75.  ,
#         84.  , 117.  ,  47.  ,  33.  , 187.  ,  29.  , 122.  , 164.  ,
#         92.  ,  55.  ,  89.  , 208.  ,  44.  ,  86.  , 150.  ,  56.1 ,
#         64.75,  99.5 ,  54.15,  60.89, 144.  ,  39.38, 341.  ,  93.6 ,
#        211.  ,  74.07, 163.  ,  83.83, 100.26,  96.25,  76.54,  60.43,
#         57.74,  66.16,  53.35,  77.98,  58.3 ,  76.5 ,  36.64,  72.86,
#         27.5 ])

# %%
df = df[df['size'] < 250]

# %%
#JAVOBINGIZNI SHUYERGA YOZING
plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='size', y='price')
plt.show()

# Bunda size 250 dan katta bo'lganlarini tashlab yubordik
# etibor bersak yuqoridagi grafikda size 400 dan katta bo'lganlar ham bor bunda esa 250 gacha

# %%
#@title Kutilgan natija
# df = df[df['size']<250]
# plt.figure(figsize=(10,6))
# sns.scatterplot(data=df, x='size', y='price')
# plt.show()

# %% [markdown]
# ### 2-VAZIFA. Uylarning narxi (price) va maydoni (size) o'rtasida bog'liqlikni ko'rsatuvchi scatter va to'g'ri chiziqni chizing.

# %%
# JAVOB UCHUN JOY
df = df[df['size'] < 250]
plt.figure(figsize=(10,6))
sns.regplot(data=df, x="size", y="price")
# regplot bilan o'suvchi korrelyatsiya bo'layotganini tekshirish mumkin
plt.show()

# %%
#@title Kutilgan natija
# plt.figure(figsize=(10,6))
# sns.regplot(data=df, x='size', y='price')
# plt.show()

# %% [markdown]
# ### 3-VAZIFA. Uylarning narxi, maydoni va xonalar soni o'rtasidagi bog'liqlikni ko'rsating.

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(data=df, x="size", y="price", hue='rooms', s=100)
plt.show()

# %%
#@title Kutilgan natija
# plt.figure(figsize=(10,6))
# sns.scatterplot(data=df, x='size', y='price', hue='rooms')
# plt.show()

# %% [markdown]
# ### 4-VAZIFA. Uylarning narxi, maydoni va tumanlar o'rtasidagi bog'liqlikni ko'rsating.

# %%
df.head(1)
# Out:
#                                             location      district  rooms  \
# 0  город Ташкент, Юнусабадский район, Юнусабад 8-...  Юнусабадский      3
#
#    size  level  max_levels  price        lat        lng
# 0  57.0      4           4  52000  41.371471  69.281049

# %%
# JAVOBNI SHUYERGA YOZING
plt.figure(figsize=(15,8))
sns.scatterplot(data=df, x="size", y="price", hue='district', s=100)
plt.show()

# %%
#@title Kutilgan natija
# plt.figure(figsize=(10,6))
# sns.scatterplot(data=df, x='size', y='price', hue='district')
# plt.show()

# %% [markdown]
# ### 5-VAZIFA. Swarm ploit yordamida turli tumanlardag uylarning narxini taqqoslang.

# %%
# JAVOB UCHUN JOY
sns.swarmplot(data=df, x=df['district'], y=df['price'])
plt.xticks(rotation=90)
plt.show()
# swarmplot - Nuqtalarni tarqatish: U ma'lumotlar nuqtalarini bir-birining ustiga chiqmasdan,
# ularning taqsimotini aniq ko'rsatish uchun "suruv" shaklida joylashtiradi. Bu, ayniqsa,
# bir kategoriya bo'yicha ko'plab nuqtalar mavjud bo'lganda foydalidir,
# chunki odatiy scatterplot da nuqtalar bir-birini yashirib qo'yishi mumkin.
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 92.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 87.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 95.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 95.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 94.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 88.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 86.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 84.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 85.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 80.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 28.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 25.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 92.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 94.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
#@title Kutilgan natija
plt.figure(figsize=(10,6))
sns.swarmplot(data=df, x='district', y='price')
plt.xticks(rotation=90)
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 86.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 80.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 93.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 92.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 90.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 80.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 78.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 73.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 73.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 65.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 80.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
