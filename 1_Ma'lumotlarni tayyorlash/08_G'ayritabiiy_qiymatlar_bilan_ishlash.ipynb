# %% [markdown]
# <a href="https://colab.research.google.com/github/sherjahong1r/my-data-sayns-lessons/blob/main/08_G'ayritabiiy_qiymatlar_bilan_ishlash.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **G'ayritabiiy qiymatlar bilan ishlash**

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://github.com/anvarnarz/praktikum_datasets/raw/main/MOCK_USER_DATA.csv", index_col=0)
df
# Out:
#     first_name   last_name                           email       gender   age
# id
# 1      Dorothy     Verryan               dverryan0@who.int   Non-binary     1
# 2      Pietrek     Scanlin          pscanlin1@yolasite.com         Male    91
# 3       Lilith    Sarjeant  lsarjeant2@creativecommons.org  Genderfluid  1233
# 4         Knox  Cunningham    kcunningham3@yellowpages.com  Genderfluid     6
# 5     Mohammed  Habbershon    mhabbershon4@sourceforge.net       Female    48
# ..         ...         ...                             ...          ...   ...
# 96        Baxy       Marcu        bmarcu2n@list-manage.com      Agender    64
# 97      Kattie     Claxson          kclaxson2o@booking.com       Female    18
# 98        Clem     Fullerd  cfullerd2p@creativecommons.org     Bigender    55
# 99   Desdemona     Jurasek        djurasek2q@aboutads.info  Genderfluid    46
# 100      Mable     Toffano          mtoffano2r@myspace.com     Bigender   233
#
# [100 rows x 5 columns]

# %%
df.shape
# Out:
# (100, 5)

# %%
df.describe()
 # Bunga etibor bersak min, max va mean yoshlarga qarasak inson yoshiga to'g'ri kelmaydigan sonlar bor.
 # Shu boisdan ularni tahrirlaymiz pastda.
# Out:
#                age
# count   100.000000
# mean    145.660000
# std     565.631411
# min     -85.000000
# 25%      22.750000
# 50%      53.500000
# 75%      84.250000
# max    4444.000000

# %%
df[df.age>123]
# 123 dan katta bo'lgan yoshlarni chiqarib oldik
# Out:
#     first_name  last_name                           email       gender   age
# id
# 3       Lilith   Sarjeant  lsarjeant2@creativecommons.org  Genderfluid  1233
# 39      Godard      Miere               gmiere12@1688.com   Polygender  3434
# 47       Cleve  Sparshatt      csparshatt1a@economist.com  Genderfluid   333
# 49       Trace   Stockney          tstockney1c@flavors.me       Female   344
# 65      Eloise    Snoddon    esnoddon1s@elegantthemes.com  Genderfluid   332
# 80       Gabie     Rothon              grothon27@ehow.com  Genderqueer  4444
# 100      Mable    Toffano          mtoffano2r@myspace.com     Bigender   233

# %%
df[df.age>123].index
# Endi 123 dan kattalarni index tartib raqami bo'yicha chiqardik
# Out:
# Index([3, 39, 47, 49, 65, 80, 100], dtype='int64', name='id')

# %%
df[df.age<0].index
# Out:
# Index([11, 19, 21, 33, 38, 90], dtype='int64', name='id')

# %%
df[(df.age<0) | (df.age>123)]
# | bu belgi yordamida ikkalasini birdaniga yozdik.
# Out:
#     first_name  last_name                           email       gender   age
# id
# 3       Lilith   Sarjeant  lsarjeant2@creativecommons.org  Genderfluid  1233
# 11      Elijah      Heine                eheinea@imdb.com     Bigender   -85
# 19       Luisa  Bradborne            lbradbornei@fema.gov       Female   -75
# 21       Levin     Worner                lwornerk@ihg.com  Genderqueer   -43
# 33    Ebenezer    Greeves           egreevesw@myspace.com         Male   -26
# 38        Hana   Langwade  hlangwade11@washingtonpost.com  Genderqueer   -42
# 39      Godard      Miere               gmiere12@1688.com   Polygender  3434
# 47       Cleve  Sparshatt      csparshatt1a@economist.com  Genderfluid   333
# 49       Trace   Stockney          tstockney1c@flavors.me       Female   344
# 65      Eloise    Snoddon    esnoddon1s@elegantthemes.com  Genderfluid   332
# 80       Gabie     Rothon              grothon27@ehow.com  Genderqueer  4444
# ...

# %%
np.abs(-30)
# abs bu manfiy qiymatlarni musbatga aylantiradi
# Out:
# np.int64(30)

# %%
df['age'] = df['age'].apply(np.abs)
df['age']
# Bunda apply yani hammasi degani va shuning ichidagi np.abs bilan df jadvalidagi barcha manfiy qiymatlarni musbat qildik.
# Hamda age ustuniga saqladik
# Out:
# id
# 1         1
# 2        91
# 3      1233
# 4         6
# 5        48
#        ...
# 96       64
# 97       18
# 98       55
# 99       46
# 100     233
# Name: age, Length: 100, dtype: int64

# %%
df
# Out:
#     first_name   last_name                           email       gender   age
# id
# 1      Dorothy     Verryan               dverryan0@who.int   Non-binary     1
# 2      Pietrek     Scanlin          pscanlin1@yolasite.com         Male    91
# 3       Lilith    Sarjeant  lsarjeant2@creativecommons.org  Genderfluid  1233
# 4         Knox  Cunningham    kcunningham3@yellowpages.com  Genderfluid     6
# 5     Mohammed  Habbershon    mhabbershon4@sourceforge.net       Female    48
# ..         ...         ...                             ...          ...   ...
# 96        Baxy       Marcu        bmarcu2n@list-manage.com      Agender    64
# 97      Kattie     Claxson          kclaxson2o@booking.com       Female    18
# 98        Clem     Fullerd  cfullerd2p@creativecommons.org     Bigender    55
# 99   Desdemona     Jurasek        djurasek2q@aboutads.info  Genderfluid    46
# 100      Mable     Toffano          mtoffano2r@myspace.com     Bigender   233
#
# [100 rows x 5 columns]

# %%
df[df.age<0]
# Endi etibor bersak manfiy yosh qiymatlari qolmagan
# Out:
# Empty DataFrame
# Columns: [first_name, last_name, email, gender, age]
# Index: []

# %% [markdown]
# manfiy qiymatlarni musbat qilib to'g'irlay oldik ammo 123 yoshdan katta bo'lgan qatorlarni o'chirishga majburmiz aynan bu jadval uchun

# %%
df[df.age>123].index
# Out:
# Index([3, 39, 47, 49, 65, 80, 100], dtype='int64', name='id')

# %%
idx = df[df.age>123].index
idx
# Out:
# Index([3, 39, 47, 49, 65, 80, 100], dtype='int64', name='id')

# %%
df.drop(index=idx, inplace=True)
df
# Bunda yoshi 123 dan katta bo'lgan qatorlar o'chirib yuborildi va inplace=True bilan asl df jadvaliga saqlandi
# Out:
#    first_name   last_name                           email       gender  age
# id
# 1     Dorothy     Verryan               dverryan0@who.int   Non-binary    1
# 2     Pietrek     Scanlin          pscanlin1@yolasite.com         Male   91
# 4        Knox  Cunningham    kcunningham3@yellowpages.com  Genderfluid    6
# 5    Mohammed  Habbershon    mhabbershon4@sourceforge.net       Female   48
# 6       Glynn      Ebbing          gebbing5@rakuten.co.jp  Genderfluid   77
# ..        ...         ...                             ...          ...  ...
# 95      Byron  Whittleton   bwhittleton2m@theatlantic.com   Non-binary    2
# 96       Baxy       Marcu        bmarcu2n@list-manage.com      Agender   64
# 97     Kattie     Claxson          kclaxson2o@booking.com       Female   18
# 98       Clem     Fullerd  cfullerd2p@creativecommons.org     Bigender   55
# 99  Desdemona     Jurasek        djurasek2q@aboutads.info  Genderfluid   46
#
# [93 rows x 5 columns]

# %%
df[df.age>123].index
# Etibor bersak 123 dan katta yoshlar qolmagan va barchasi o'chirib yuborilgan
# Out:
# Index([], dtype='int64', name='id')

# %%
df.describe()
# Endi bunda min, max va mean ga qarasak ancha yosh ko'rsatgichlari normallashgan.
# Out:
#               age
# count   93.000000
# mean    52.612903
# std     29.978265
# min      1.000000
# 25%     29.000000
# 50%     52.000000
# 75%     77.000000
# max    100.000000

# %%
df
# Out:
#    first_name   last_name                           email       gender  age
# id
# 1     Dorothy     Verryan               dverryan0@who.int   Non-binary    1
# 2     Pietrek     Scanlin          pscanlin1@yolasite.com         Male   91
# 4        Knox  Cunningham    kcunningham3@yellowpages.com  Genderfluid    6
# 5    Mohammed  Habbershon    mhabbershon4@sourceforge.net       Female   48
# 6       Glynn      Ebbing          gebbing5@rakuten.co.jp  Genderfluid   77
# ..        ...         ...                             ...          ...  ...
# 95      Byron  Whittleton   bwhittleton2m@theatlantic.com   Non-binary    2
# 96       Baxy       Marcu        bmarcu2n@list-manage.com      Agender   64
# 97     Kattie     Claxson          kclaxson2o@booking.com       Female   18
# 98       Clem     Fullerd  cfullerd2p@creativecommons.org     Bigender   55
# 99  Desdemona     Jurasek        djurasek2q@aboutads.info  Genderfluid   46
#
# [93 rows x 5 columns]

# %%
df['gender'].unique()
# Out:
# array(['Non-binary', 'Male', 'Genderfluid', 'Female', 'Agender',
#        'Bigender', 'Polygender', 'Genderqueer'], dtype=object)

# %%
df.gender.value_counts()
# df jadvalidagi gender ustuniga ahamiyat bersak 8 turdagi jins vakillari mavjud
# Out:
# gender
# Male           21
# Bigender       12
# Female         11
# Genderfluid    11
# Non-binary     10
# Genderqueer    10
# Agender         9
# Polygender      9
# Name: count, dtype: int64

# %% [markdown]
# Agar hohlasak bu gender ustunini ham tahrirlab faqat Male va Female jins vakillarini qoldirishimiz mumkin

# %%
df.shape
# Asl df jadvali 100 qator edi va 123 dan katta bo'lgan qatorlarni o'chirganimizdan so'ng 93 qator qolgan edi.
# Out:
# (93, 5)

# %%
df2 = df[df.gender.isin(['Male','Female'])]
df2
# Out:
#    first_name     last_name                         email  gender  age
# id
# 2     Pietrek       Scanlin        pscanlin1@yolasite.com    Male   91
# 5    Mohammed    Habbershon  mhabbershon4@sourceforge.net  Female   48
# 10      David      Meredyth    dmeredyth9@telegraph.co.uk  Female   68
# 12  Raffaello     Firminger     rfirmingerb@bloomberg.com  Female   74
# 17      Byram   Martynikhin     bmartynikhing@jiathis.com    Male   40
# 19      Luisa     Bradborne          lbradbornei@fema.gov  Female   75
# 22        Ray         Padly           rpadlyl@twitpic.com    Male   85
# 26   Ephrayim    Westmacott         ewestmacottp@ning.com    Male   77
# 29      Biron      Acklands        backlandss@comsenz.com    Male   13
# 33   Ebenezer       Greeves         egreevesw@myspace.com    Male   26
# 34     Brooks          Vose             bvosex@amazon.com  Female   34
# 36        Axe       Arundel           aarundelz@yahoo.com  Female   14
# ...

# %%
df2.shape
# Demak Male va Female 32 qatorda mavjud ekan
# Out:
# (32, 5)

# %%
df
# Out:
#    first_name   last_name                           email       gender  age
# id
# 1     Dorothy     Verryan               dverryan0@who.int   Non-binary    1
# 2     Pietrek     Scanlin          pscanlin1@yolasite.com         Male   91
# 4        Knox  Cunningham    kcunningham3@yellowpages.com  Genderfluid    6
# 5    Mohammed  Habbershon    mhabbershon4@sourceforge.net       Female   48
# 6       Glynn      Ebbing          gebbing5@rakuten.co.jp  Genderfluid   77
# ..        ...         ...                             ...          ...  ...
# 95      Byron  Whittleton   bwhittleton2m@theatlantic.com   Non-binary    2
# 96       Baxy       Marcu        bmarcu2n@list-manage.com      Agender   64
# 97     Kattie     Claxson          kclaxson2o@booking.com       Female   18
# 98       Clem     Fullerd  cfullerd2p@creativecommons.org     Bigender   55
# 99  Desdemona     Jurasek        djurasek2q@aboutads.info  Genderfluid   46
#
# [93 rows x 5 columns]
