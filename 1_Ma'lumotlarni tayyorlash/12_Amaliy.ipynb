# %% [markdown]
# <a href="https://colab.research.google.com/github/sherjahong1r/my-data-sayns-lessons/blob/main/12_Amaliy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Avvalgi amaliyotda GitHubga yuklangan melb_data.csv faylni df ga chaqirib oling**

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/sherjahong1r/my-data-sayns-lessons/main/1_Ma'lumotlarni%20tayyorlash/melb_data%20(1).csv"

df = pd.read_csv(url)

df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# 0        NaN        Yarra  -37.7996    144.9984  Northern Metropolitan
# 1     1900.0        Yarra  -37.8079    144.9934  Northern Metropolitan
# 2     1900.0        Yarra  -37.8093    144.9944  Northern Metropolitan
# 3        NaN        Yarra  -37.7969    144.9969  Northern Metropolitan
# 4     2014.0        Yarra  -37.8072    144.9941  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 2        4019.0
# 3        4019.0
# 4        4019.0
#
# [5 rows x 21 columns]

# %% [markdown]
# !wget bilan o'qishning yana bir usuli

# %%
# !wget "https://raw.githubusercontent.com/sherjahong1r/my-data-sayns-lessons/main/1_Ma'lumotlarni%20tayyorlash/melb_data%20(1).csv"
# Out:
# --2026-01-16 12:03:12--  https://raw.githubusercontent.com/sherjahong1r/my-data-sayns-lessons/main/1_Ma'lumotlarni%20tayyorlash/melb_data%20(1).csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2091239 (2.0M) [text/plain]
# Saving to: ‘melb_data (1).csv.2’
#
# melb_data (1).csv.2 100%[===================>]   1.99M  --.-KB/s    in 0.06s
#
# 2026-01-16 12:03:12 (33.7 MB/s) - ‘melb_data (1).csv.2’ saved [2091239/2091239]

# %%
import pandas as pd

df = pd.read_csv("melb_data (1).csv")
df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# 0        NaN        Yarra  -37.7996    144.9984  Northern Metropolitan
# 1     1900.0        Yarra  -37.8079    144.9934  Northern Metropolitan
# 2     1900.0        Yarra  -37.8093    144.9944  Northern Metropolitan
# 3        NaN        Yarra  -37.7969    144.9969  Northern Metropolitan
# 4     2014.0        Yarra  -37.8072    144.9941  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 2        4019.0
# 3        4019.0
# 4        4019.0
#
# [5 rows x 21 columns]

# %% [markdown]
# 🔺 DIQQAT!
# Agar alohida aytilmagan bo'lsa, dfga kiritilgan o'zgartirishlarni saqlamang (inplace=False)
#
# # **1-VAZIFA. df dagi barcha ustunlardagiNaN qiymatlar sonini chiqaring**

# %%
df.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %% [markdown]
# # **2-VAZIFA. df barcha NaN qiymatlarni 0 bilan almashtiring**

# %%
df.fillna(0).head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           0.0
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           0.0
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# 0        0.0        Yarra  -37.7996    144.9984  Northern Metropolitan
# 1     1900.0        Yarra  -37.8079    144.9934  Northern Metropolitan
# 2     1900.0        Yarra  -37.8093    144.9944  Northern Metropolitan
# 3        0.0        Yarra  -37.7969    144.9969  Northern Metropolitan
# 4     2014.0        Yarra  -37.8072    144.9941  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 2        4019.0
# 3        4019.0
# 4        4019.0
#
# [5 rows x 21 columns]

# %% [markdown]
# # **3-VAZIFA. Quyidagi 2 ustun uchun o'rta qiymatlarni hisoblang:**
# ## **BuildingArea**
# ## **YearBuilt (butun son qaytishi kerak)**

# %%
first = df['BuildingArea'].mean()
second = int(df['YearBuilt'].mean())

print(f"BuildingArea ustunining o'rtacha qiymati: {first}")
print(f"YearBuilt ustunining o'rtacha qiymati (butun son): {second}")
# Out:
# BuildingArea ustunining o'rtacha qiymati: 151.96764988779805
# YearBuilt ustunining o'rtacha qiymati (butun son): 1964

# %% [markdown]
# # **4-VAZIFA: BuildingArea va YearBuilt ustunlaridagi NaN qiymatlarni shu sutun uchun o'rta qiymatlar bilan almashtiring**

# %%
df.fillna({'BuildingArea': first, 'YearBuilt': second})
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 0        Biggin   3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0
# 1        Biggin   4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0
# 2        Biggin   4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0
# 3        Biggin   4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0
# 4        Nelson   4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0
# ...         ...         ...       ...       ...  ...       ...  ...       ...
# 13575     Barry  26/08/2017      16.7    3150.0  ...       2.0  2.0     652.0
# 13576  Williams  26/08/2017       6.8    3016.0  ...       2.0  2.0     333.0
# 13577     Raine  26/08/2017       6.8    3016.0  ...       2.0  4.0     436.0
# 13578   Sweeney  26/08/2017       6.8    3016.0  ...       1.0  5.0     866.0
# 13579   Village  26/08/2017       6.3    3013.0  ...       1.0  1.0     362.0
#
#        BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 0         151.96765     1964.0        Yarra -37.79960   144.99840
# 1          79.00000     1900.0        Yarra -37.80790   144.99340
# 2         150.00000     1900.0        Yarra -37.80930   144.99440
# 3         151.96765     1964.0        Yarra -37.79690   144.99690
# 4         142.00000     2014.0        Yarra -37.80720   144.99410
# ...             ...        ...          ...       ...         ...
# 13575     151.96765     1981.0          NaN -37.90562   145.16761
# 13576     133.00000     1995.0          NaN -37.85927   144.87904
# 13577     151.96765     1997.0          NaN -37.85274   144.88738
# 13578     157.00000     1920.0          NaN -37.85908   144.89299
# 13579     112.00000     1920.0          NaN -37.81188   144.88449
#
#                        Regionname Propertycount
# 0           Northern Metropolitan        4019.0
# 1           Northern Metropolitan        4019.0
# 2           Northern Metropolitan        4019.0
# 3           Northern Metropolitan        4019.0
# 4           Northern Metropolitan        4019.0
# ...                           ...           ...
# 13575  South-Eastern Metropolitan        7392.0
# 13576        Western Metropolitan        6380.0
# 13577        Western Metropolitan        6380.0
# 13578        Western Metropolitan        6380.0
# 13579        Western Metropolitan        6543.0
#
# [13580 rows x 21 columns]

# %% [markdown]
# # yana bir usuli

# %%
df.fillna({'BuildingArea':151.9, "YearBuilt":1964})
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 0        Biggin   3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0
# 1        Biggin   4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0
# 2        Biggin   4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0
# 3        Biggin   4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0
# 4        Nelson   4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0
# ...         ...         ...       ...       ...  ...       ...  ...       ...
# 13575     Barry  26/08/2017      16.7    3150.0  ...       2.0  2.0     652.0
# 13576  Williams  26/08/2017       6.8    3016.0  ...       2.0  2.0     333.0
# 13577     Raine  26/08/2017       6.8    3016.0  ...       2.0  4.0     436.0
# 13578   Sweeney  26/08/2017       6.8    3016.0  ...       1.0  5.0     866.0
# 13579   Village  26/08/2017       6.3    3013.0  ...       1.0  1.0     362.0
#
#        BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 0             151.9     1964.0        Yarra -37.79960   144.99840
# 1              79.0     1900.0        Yarra -37.80790   144.99340
# 2             150.0     1900.0        Yarra -37.80930   144.99440
# 3             151.9     1964.0        Yarra -37.79690   144.99690
# 4             142.0     2014.0        Yarra -37.80720   144.99410
# ...             ...        ...          ...       ...         ...
# 13575         151.9     1981.0          NaN -37.90562   145.16761
# 13576         133.0     1995.0          NaN -37.85927   144.87904
# 13577         151.9     1997.0          NaN -37.85274   144.88738
# 13578         157.0     1920.0          NaN -37.85908   144.89299
# 13579         112.0     1920.0          NaN -37.81188   144.88449
#
#                        Regionname Propertycount
# 0           Northern Metropolitan        4019.0
# 1           Northern Metropolitan        4019.0
# 2           Northern Metropolitan        4019.0
# 3           Northern Metropolitan        4019.0
# 4           Northern Metropolitan        4019.0
# ...                           ...           ...
# 13575  South-Eastern Metropolitan        7392.0
# 13576        Western Metropolitan        6380.0
# 13577        Western Metropolitan        6380.0
# 13578        Western Metropolitan        6380.0
# 13579        Western Metropolitan        6543.0
#
# [13580 rows x 21 columns]

# %% [markdown]
# # **5-VAZIFA. .groupby()**
# Ustun uchun o'rta qiymat har doim ham aniq bo'lavermaydi. Keling avval YearBuilt ustuni uchun aniqroq qiymat topishga harakat qilamiz.
#
# Buning uchun Regionname ustuni qiymatlaridan foydalanishimiz mumkin, ya'ni bir Regiondagi binolar tahminan bir hil yillarda qurilgan deb tahmin qilsak bo'ladi.

# %%
df.groupby(['Regionname']).YearBuilt.mean().astype(int)
# Out:
# Regionname
# Eastern Metropolitan          1971
# Eastern Victoria              1984
# Northern Metropolitan         1962
# Northern Victoria             1986
# South-Eastern Metropolitan    1976
# Southern Metropolitan         1960
# Western Metropolitan          1968
# Western Victoria              1982
# Name: YearBuilt, dtype: int64

# %% [markdown]
# # **5.2. df YearBuilt ustunidagi NaN qiymatlarni yuqoridagi qiymatlar bilan almashtiring.**
# df[df.Regionname='Eastern Metropolitan']=...
#
# Har bir Regionname uchun qiymatlarni bittalab kiritmaslik uchun for siklidan foydalanishingiz mumkin.

# %%
groups = df.groupby(['Regionname']).YearBuilt.mean() # Bu Series obyekti
for idx in groups.index:
   df[df.Regionname==idx] = df[df.Regionname==idx].fillna({'YearBuilt':groups[idx]})

# %%
groups
# Out:
# Regionname
# Eastern Metropolitan          1971.859903
# Eastern Victoria              1984.032258
# Northern Metropolitan         1962.764286
# Northern Victoria             1986.666667
# South-Eastern Metropolitan    1976.859504
# Southern Metropolitan         1960.523777
# Western Metropolitan          1968.155192
# Western Victoria              1982.565217
# Name: YearBuilt, dtype: float64

# %% [markdown]
# # **YearBuilt uchun yana ham aniqroq o'rta qiymat hisoblashning qanday yo'lini taklif qilgan bo'lar edingiz?**

# %%
df['YearBuilt'].fillna(method='ffill')
# Out:
# /tmp/ipython-input-283134917.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['YearBuilt'].fillna(method='ffill')
# 0        1962.764286
# 1        1900.000000
# 2        1900.000000
# 3        1962.764286
# 4        2014.000000
#             ...
# 13575    1981.000000
# 13576    1995.000000
# 13577    1997.000000
# 13578    1920.000000
# 13579    1920.000000
# Name: YearBuilt, Length: 13580, dtype: float64

# %% [markdown]
# # **6-VAZIFA. BuildingArea ustunidagi NaN qiymatlarni to'ldiramiz**
# BuildingArea bino qurilgan yerning maydonini bildiradi. Bu qiymatlarni tahmin qilish uchun qaysi ustun qiymatlaridan foydalanish to'g'ri deb hisoblaysiz?

# %%
df.shape
# Out:
# (13580, 21)
# (13580, 21)

# %%
df.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt           0
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
df['BuildingArea'].isnull().sum()
# Demak 6450 ta NaN qator mavju ekan BuildingArea ustunida.
# Out:
# np.int64(6450)

# %%
import numpy as np
np.mean(df['BuildingArea'])
# Out:
# np.float64(151.96764988779805)

# %%
df.fillna(np.mean(df['BuildingArea']))
# NaN lar o'rniga BuildingArea ning o'rtacha qiymati qo'yildi
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 0        Biggin   3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0
# 1        Biggin   4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0
# 2        Biggin   4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0
# 3        Biggin   4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0
# 4        Nelson   4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0
# ...         ...         ...       ...       ...  ...       ...  ...       ...
# 13575     Barry  26/08/2017      16.7    3150.0  ...       2.0  2.0     652.0
# 13576  Williams  26/08/2017       6.8    3016.0  ...       2.0  2.0     333.0
# 13577     Raine  26/08/2017       6.8    3016.0  ...       2.0  4.0     436.0
# 13578   Sweeney  26/08/2017       6.8    3016.0  ...       1.0  5.0     866.0
# 13579   Village  26/08/2017       6.3    3013.0  ...       1.0  1.0     362.0
#
#        BuildingArea    YearBuilt  CouncilArea Lattitude  Longtitude  \
# 0         151.96765  1962.764286        Yarra -37.79960   144.99840
# 1          79.00000  1900.000000        Yarra -37.80790   144.99340
# 2         150.00000  1900.000000        Yarra -37.80930   144.99440
# 3         151.96765  1962.764286        Yarra -37.79690   144.99690
# 4         142.00000  2014.000000        Yarra -37.80720   144.99410
# ...             ...          ...          ...       ...         ...
# 13575     151.96765  1981.000000    151.96765 -37.90562   145.16761
# 13576     133.00000  1995.000000    151.96765 -37.85927   144.87904
# 13577     151.96765  1997.000000    151.96765 -37.85274   144.88738
# 13578     157.00000  1920.000000    151.96765 -37.85908   144.89299
# 13579     112.00000  1920.000000    151.96765 -37.81188   144.88449
#
#                        Regionname Propertycount
# 0           Northern Metropolitan        4019.0
# 1           Northern Metropolitan        4019.0
# 2           Northern Metropolitan        4019.0
# 3           Northern Metropolitan        4019.0
# 4           Northern Metropolitan        4019.0
# ...                           ...           ...
# 13575  South-Eastern Metropolitan        7392.0
# 13576        Western Metropolitan        6380.0
# 13577        Western Metropolitan        6380.0
# 13578        Western Metropolitan        6380.0
# 13579        Western Metropolitan        6543.0
#
# [13580 rows x 21 columns]

# %% [markdown]
# # **6.1 dfni xonalar soni bo'yicha o'rta qiymat olib ko'ring**

# %%
df
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 0        Biggin   3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0
# 1        Biggin   4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0
# 2        Biggin   4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0
# 3        Biggin   4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0
# 4        Nelson   4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0
# ...         ...         ...       ...       ...  ...       ...  ...       ...
# 13575     Barry  26/08/2017      16.7    3150.0  ...       2.0  2.0     652.0
# 13576  Williams  26/08/2017       6.8    3016.0  ...       2.0  2.0     333.0
# 13577     Raine  26/08/2017       6.8    3016.0  ...       2.0  4.0     436.0
# 13578   Sweeney  26/08/2017       6.8    3016.0  ...       1.0  5.0     866.0
# 13579   Village  26/08/2017       6.3    3013.0  ...       1.0  1.0     362.0
#
#        BuildingArea    YearBuilt  CouncilArea Lattitude  Longtitude  \
# 0               NaN  1962.764286        Yarra -37.79960   144.99840
# 1              79.0  1900.000000        Yarra -37.80790   144.99340
# 2             150.0  1900.000000        Yarra -37.80930   144.99440
# 3               NaN  1962.764286        Yarra -37.79690   144.99690
# 4             142.0  2014.000000        Yarra -37.80720   144.99410
# ...             ...          ...          ...       ...         ...
# 13575           NaN  1981.000000          NaN -37.90562   145.16761
# 13576         133.0  1995.000000          NaN -37.85927   144.87904
# 13577           NaN  1997.000000          NaN -37.85274   144.88738
# 13578         157.0  1920.000000          NaN -37.85908   144.89299
# 13579         112.0  1920.000000          NaN -37.81188   144.88449
#
#                        Regionname Propertycount
# 0           Northern Metropolitan        4019.0
# 1           Northern Metropolitan        4019.0
# 2           Northern Metropolitan        4019.0
# 3           Northern Metropolitan        4019.0
# 4           Northern Metropolitan        4019.0
# ...                           ...           ...
# 13575  South-Eastern Metropolitan        7392.0
# 13576        Western Metropolitan        6380.0
# 13577        Western Metropolitan        6380.0
# 13578        Western Metropolitan        6380.0
# 13579        Western Metropolitan        6543.0
#
# [13580 rows x 21 columns]

# %% [markdown]
# Yuqoridagi Dataframe Melburn shahri uchun sotuvdagi uylar haqida m'lumotlarni jamlagan.
#
# Quyida jadvalning ba'zi sutunlari tarjimasi berilgan (qolganini o'zingiz Google yordamida tarjima qilishingiz mumkin):
#
# Room - xonalar soni
#
# Type - uyning turi (h - villa/kottej/hovli; u - kvartira; t - shahardagi hovli)
#
# Price - narx
#
# Bathroom - tualet-vanna
#
# Landsize - yerning maydoni (hovli uchun)
#
# BuildingArea - Bino qurilgan yerning maydoni
#
# YearBuilt - qurilgan yili
#
# Lattitude va Longitude - GPS kordinatalar
#
# Regionname - Region

# %%
np.mean(df['Rooms'])
# Out:
# np.float64(2.9379970544919)

# %% [markdown]
# # **6.2 Xonalar va uy turi bo'yicha o'rta qiymatni olib ko'ring.**

# %%
df.groupby('Type')['Rooms'].mean()
# Out:
# Type
# h    3.260874
# t    2.837522
# u    1.963871
# Name: Rooms, dtype: float64

# %% [markdown]
# # **6.3 Ahamiyat bering, 10 xonalik uylar uchun o'rta qiymat chiqmayapti. Bu nimadan dalolat beradi? Jami 10 xonalik uylar nechta? Ular bilan qanday yo'l tutishni maslahat berasiz?**

# %%
# 'Rooms' ustunidagi noyob qiymatlarni va ularning sonini ko'rib chiqamiz
display(df['Rooms'].value_counts().sort_index())

# Jami 10 xonalik uylar sonini aniqlaymiz
ten_room_houses_count = df[df['Rooms'] == 10].shape[0]
print(f"Jami 10 xonalik uylar soni: {ten_room_houses_count}")

if ten_room_houses_count == 0:
    print("Ma'lumotlar to'plamida 10 xonalik uylar mavjud emas, shuning uchun ularning o'rtacha qiymati hisoblanmagan.")
    print("Agar 10 xonalik uylar mavjud bo'lmagani uchun o'rtacha qiymat chiqmagan bo'lsa, bu ustunni o'zgartirish shart emas.")
else:
    print("10 xonalik uylar mavjud. Agar ularning soni juda oz bo'lsa, ularni boshqa kattaroq xonali uylar bilan guruhlash yoki alohida tahlil qilishni ko'rib chiqishingiz mumkin.")
# Out:
# Rooms
# 1      681
# 2     3648
# 3     5881
# 4     2688
# 5      596
# 6       67
# 7       10
# 8        8
# 10       1
# Name: count, dtype: int64
# Jami 10 xonalik uylar soni: 1
# 10 xonalik uylar mavjud. Agar ularning soni juda oz bo'lsa, ularni boshqa kattaroq xonali uylar bilan guruhlash yoki alohida tahlil qilishni ko'rib chiqishingiz mumkin.

# %% [markdown]
# # **6.4 BuildingArea ustunidagi mavjud NaN qiymatlarni o'zingiz to'g'ri deb bilgan usul bilan to'ldiring**

# %%
df.fillna(np.mean(df['BuildingArea']))
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 0        Biggin   3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0
# 1        Biggin   4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0
# 2        Biggin   4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0
# 3        Biggin   4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0
# 4        Nelson   4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0
# ...         ...         ...       ...       ...  ...       ...  ...       ...
# 13575     Barry  26/08/2017      16.7    3150.0  ...       2.0  2.0     652.0
# 13576  Williams  26/08/2017       6.8    3016.0  ...       2.0  2.0     333.0
# 13577     Raine  26/08/2017       6.8    3016.0  ...       2.0  4.0     436.0
# 13578   Sweeney  26/08/2017       6.8    3016.0  ...       1.0  5.0     866.0
# 13579   Village  26/08/2017       6.3    3013.0  ...       1.0  1.0     362.0
#
#        BuildingArea    YearBuilt  CouncilArea Lattitude  Longtitude  \
# 0         151.96765  1962.764286        Yarra -37.79960   144.99840
# 1          79.00000  1900.000000        Yarra -37.80790   144.99340
# 2         150.00000  1900.000000        Yarra -37.80930   144.99440
# 3         151.96765  1962.764286        Yarra -37.79690   144.99690
# 4         142.00000  2014.000000        Yarra -37.80720   144.99410
# ...             ...          ...          ...       ...         ...
# 13575     151.96765  1981.000000    151.96765 -37.90562   145.16761
# 13576     133.00000  1995.000000    151.96765 -37.85927   144.87904
# 13577     151.96765  1997.000000    151.96765 -37.85274   144.88738
# 13578     157.00000  1920.000000    151.96765 -37.85908   144.89299
# 13579     112.00000  1920.000000    151.96765 -37.81188   144.88449
#
#                        Regionname Propertycount
# 0           Northern Metropolitan        4019.0
# 1           Northern Metropolitan        4019.0
# 2           Northern Metropolitan        4019.0
# 3           Northern Metropolitan        4019.0
# 4           Northern Metropolitan        4019.0
# ...                           ...           ...
# 13575  South-Eastern Metropolitan        7392.0
# 13576        Western Metropolitan        6380.0
# 13577        Western Metropolitan        6380.0
# 13578        Western Metropolitan        6380.0
# 13579        Western Metropolitan        6543.0
#
# [13580 rows x 21 columns]

# %% [markdown]
# # **7-VAZIFA. Yuqoridagi vazifalardan so'ng, bizda faqatgina CouncilArea ustunida NaN qiymatlar qolishi kerak xolos.**
# Bu ustundagi NaN qiymatlarni avvalgi qatordagi qiymatlar bilan to'ldirib keting. Natijani saqlab qoling

# %%
df['CouncilArea'].fillna(method='ffill', inplace=True)
df
# Out:
# /tmp/ipython-input-2109442157.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['CouncilArea'].fillna(method='ffill', inplace=True)
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 0        Biggin   3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0
# 1        Biggin   4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0
# 2        Biggin   4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0
# 3        Biggin   4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0
# 4        Nelson   4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0
# ...         ...         ...       ...       ...  ...       ...  ...       ...
# 13575     Barry  26/08/2017      16.7    3150.0  ...       2.0  2.0     652.0
# 13576  Williams  26/08/2017       6.8    3016.0  ...       2.0  2.0     333.0
# 13577     Raine  26/08/2017       6.8    3016.0  ...       2.0  4.0     436.0
# 13578   Sweeney  26/08/2017       6.8    3016.0  ...       1.0  5.0     866.0
# 13579   Village  26/08/2017       6.3    3013.0  ...       1.0  1.0     362.0
#
#        BuildingArea    YearBuilt  CouncilArea Lattitude  Longtitude  \
# 0               NaN  1962.764286        Yarra -37.79960   144.99840
# 1              79.0  1900.000000        Yarra -37.80790   144.99340
# 2             150.0  1900.000000        Yarra -37.80930   144.99440
# 3               NaN  1962.764286        Yarra -37.79690   144.99690
# 4             142.0  2014.000000        Yarra -37.80720   144.99410
# ...             ...          ...          ...       ...         ...
# 13575           NaN  1981.000000  Maribyrnong -37.90562   145.16761
# 13576         133.0  1995.000000  Maribyrnong -37.85927   144.87904
# 13577           NaN  1997.000000  Maribyrnong -37.85274   144.88738
# 13578         157.0  1920.000000  Maribyrnong -37.85908   144.89299
# 13579         112.0  1920.000000  Maribyrnong -37.81188   144.88449
#
#                        Regionname Propertycount
# 0           Northern Metropolitan        4019.0
# 1           Northern Metropolitan        4019.0
# 2           Northern Metropolitan        4019.0
# 3           Northern Metropolitan        4019.0
# 4           Northern Metropolitan        4019.0
# ...                           ...           ...
# 13575  South-Eastern Metropolitan        7392.0
# 13576        Western Metropolitan        6380.0
# 13577        Western Metropolitan        6380.0
# 13578        Western Metropolitan        6380.0
# 13579        Western Metropolitan        6543.0
#
# [13580 rows x 21 columns]

# %%
df.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt           0
# CouncilArea         0
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64
