# %% [markdown]
# <a href="https://colab.research.google.com/github/sherjahong1r/my-data-sayns-lessons/blob/main/3_Lug'atdan_Series_yaratish.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from pandas import Series

# %%
obj2=Series([6, 3, 4, 5, 1], index=['a', 'b', 'c', 'd', 'e']) # bu orqali Indexlarni o'zimiz yaratamiz

# %%
print(obj2)
# Out:
# a    6
# b    3
# c    4
# d    5
# e    1
# dtype: int64

# %%
np.exp(obj2)
# Out:
# a    403.428793
# b     20.085537
# c     54.598150
# d    148.413159
# e      2.718282
# dtype: float64

# %%
obj2
# Out:
# a    6
# b    3
# c    4
# d    5
# e    1
# dtype: int64

# %%
cars_dict = {'Malibu':40000, 'Lacetti':20000, 'Toyota':45000, 'Mazda':52000, 'Honda':38000}

# %%
type(cars_dict)
# Out:
# dict

# %%
cars1 = Series(cars_dict)

# %%
cars1
# Out:
# Malibu     40000
# Lacetti    20000
# Toyota     45000
# Mazda      52000
# Honda      38000
# dtype: int64

# %%
type(cars1)
# Out:
# pandas.core.series.Series

# %%
cars1 = Series({'Malibu':40000, 'Lacetti':20000, 'Toyota':45000, 'Mazda':52000, 'Honda':38000})

# %%
cars1
# Out:
# Malibu     40000
# Lacetti    20000
# Toyota     45000
# Mazda      52000
# Honda      38000
# dtype: int64

# %%
'Malibu' in cars1
# Out:
# True

# %%
"Nexia" in cars1
# Out:
# False

# %%
cars1['Toyota']
# Out:
# np.int64(45000)

# %%
cars_dict
# Out:
# {'Malibu': 40000,
#  'Lacetti': 20000,
#  'Toyota': 45000,
#  'Mazda': 52000,
#  'Honda': 38000}

# %%
models = ['Honda', 'Mazda', 'Lacetti', 'Jaguar', 'Malibu', 'Toyota', 'BMW', 'Mercedes'] # Yuqoridagi cars1 ichiga yangi modellar qo'shilib ro'yxat yaratildi

# %%
cars2 = Series(cars_dict, index=models) # Hamda index ni models bo'yicha o'qi va yangi mashinalar narxi bo'lmagani uchun o'rnini non qiladi

# %%
cars2
# Out:
# Honda       38000.0
# Mazda       52000.0
# Lacetti     20000.0
# Jaguar          NaN
# Malibu      40000.0
# Toyota      45000.0
# BMW             NaN
# Mercedes        NaN
# dtype: float64

# %% [markdown]
# # Bu yerdan 3 - dars boshlangan yuqoridagi 2 - dars edi.

# %%
cars2.isnull() # Qiymati yo'q mashinalarni True deb chiqaradi
# Out:
# Honda       False
# Mazda       False
# Lacetti     False
# Jaguar       True
# Malibu      False
# Toyota      False
# BMW          True
# Mercedes     True
# dtype: bool

# %%
cars2.notnull() # Bu yuqoridagining aksi
# Out:
# Honda        True
# Mazda        True
# Lacetti      True
# Jaguar      False
# Malibu       True
# Toyota       True
# BMW         False
# Mercedes    False
# dtype: bool

# %%
cars1
# Out:
# Malibu     40000
# Lacetti    20000
# Toyota     45000
# Mazda      52000
# Honda      38000
# dtype: int64

# %%
cars2
# Out:
# Honda       38000.0
# Mazda       52000.0
# Lacetti     20000.0
# Jaguar          NaN
# Malibu      40000.0
# Toyota      45000.0
# BMW             NaN
# Mercedes        NaN
# dtype: float64

# %%
cars1 + cars2 # Bunda cars1 va cars2 ning joyi chalkashgan bo'lsa ham qiymati va nomi tenglarni qo'shadi
# Out:
# BMW              NaN
# Honda        76000.0
# Jaguar           NaN
# Lacetti      40000.0
# Malibu       80000.0
# Mazda       104000.0
# Mercedes         NaN
# Toyota       90000.0
# dtype: float64

# %%
cars2.name = 'Avtosalon'

# %%
cars2.index.name = 'Modellar'

# %%
cars2 # Bunda nomini avtosalon va indexni modellar deb chiqaradi yuqoridagilar asosida.
# Out:
# Modellar
# Honda       38000.0
# Mazda       52000.0
# Lacetti     20000.0
# Jaguar          NaN
# Malibu      40000.0
# Toyota      45000.0
# BMW             NaN
# Mercedes        NaN
# Name: Avtosalon, dtype: float64

# %% [markdown]
# ## Series obyektiga oid ba'zi parametrlar va metodlar

# %% [markdown]
# ## Series obyektining o'zini ham indekslarini ham nomlash mumkin:

# %%
cars2.name = 'Avtosalon'

# %%
cars2.index.name = 'Car Model'

# %%
cars2
# Out:
# Car Model
# Honda       38000.0
# Mazda       52000.0
# Lacetti     20000.0
# Jaguar          NaN
# Malibu      40000.0
# Toyota      45000.0
# BMW             NaN
# Mercedes        NaN
# Name: Avtosalon, dtype: float64

# %%
cars2.name
# Out:
# 'Avtosalon'

# %%
cars2.index # indekslar
# Out:
# Index(['Honda', 'Mazda', 'Lacetti', 'Jaguar', 'Malibu', 'Toyota', 'BMW',
#        'Mercedes'],
#       dtype='object', name='Car Model')

# %%
cars2.values # qiymatlar
# Out:
# array([38000., 52000., 20000.,    nan, 40000., 45000.,    nan,    nan])

# %%
cars2.hasnans # NaN qiymatlar bor (True) yo'qligi (False)
# Out:
# True

# %%
cars2.dtype # qiymatlarning ma'lumot turi
# Out:
# dtype('float64')

# %%
cars2.is_unique # qiymatlar takrorlanmas ekanini tekshirish
# Out:
# False

# %%
cars2.shape # Series hajmi
# Out:
# (8,)

# %%
cars2.size # Series hajmi
# Out:
# 8

# %%
cars2.iloc[2] # ma'lumotlarga indeks tartib raqami bo'yicha murojaat qilish
# Out:
# np.float64(20000.0)

# %%
cars2.iloc[-1]
# Out:
# np.float64(nan)

# %%
cars2['Honda'] # ma'lumotlarga indeks bo'yicha murojaat qilish
# Out:
# np.float64(38000.0)

# %%
cars2.loc['Toyota'] # ma'lumotlarga indeks bo'yicha murojaat qilish
# Out:
# np.float64(45000.0)

# %%
cars2.max() # max qiymat
# Out:
# 52000.0

# %%
cars2.min() # min qiymat
# Out:
# 20000.0

# %%
cars2.mean() # o'rtacha qiymat
# Out:
# np.float64(39000.0)
