# %% [markdown]
# <a href="https://colab.research.google.com/github/sherjahong1r/my-data-sayns-lessons/blob/main/21_Dataset_Statistikasi__Umumlashtiruvchi__malumotlar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Dataset Statistikasi: Umumlashtiruvchi malumotlar**

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/merc.csv')
df.head() # Onlayn bozordagi mersadesBens mashinalarining narxi
# Malumot uchun
# Model - nomi, year - yili, price - narxi, transmission - karobkasi, mileage - qancha yurgani, fuelType - nimada yurishi (Pertrol, Hybrid - elktr degani),
# tax - mashinaga beriladigan soliq, mpg - 1 galonga qancha km yurishi, engineSize - mashina matori hajmi 1.8 , 2.1 kabi.
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0        SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1    S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2   SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3    G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4    G Class  2016  73948    Automatic     4000   Petrol  325  30.1
#
#    engineSize
# 0         1.8
# 1         2.1
# 2         5.5
# 3         4.0
# 4         4.0

# %%
df.shape # 13119 ta qator va 9 ta ustun
# Out:
# (13119, 9)

# %%
df.tail() # Oxiridan 5 ta qiymatni ko'rsatadi
# Out:
#             model  year  price transmission  mileage fuelType  tax   mpg  \
# 13114     C Class  2020  35999    Automatic      500   Diesel  145  55.4
# 13115     B Class  2020  24699    Automatic     2500   Diesel  145  55.4
# 13116   GLC Class  2019  30999    Automatic    11612   Diesel  145  41.5
# 13117   CLS Class  2019  37990    Automatic     2426   Diesel  145  45.6
# 13118     S Class  2019  54999    Automatic     2075   Diesel  145  52.3
#
#        engineSize
# 13114         2.0
# 13115         2.0
# 13116         2.1
# 13117         2.0
# 13118         2.9

# %%
df.sample(10) # qiymatiga qarab taxminy mashinalarni chiqaradi, bu yerda 10.
# Out:
#            model  year  price transmission  mileage fuelType  tax    mpg  \
# 3637     E Class  2019  31995    Automatic     5853   Diesel  145   45.6
# 6947   GLE Class  2017  30199    Semi-Auto    23632   Diesel  145   47.9
# 5826     E Class  2019  41890    Automatic     3244   Hybrid  135  176.6
# 2970     E Class  2019  27980    Semi-Auto    14479   Diesel  145   61.4
# 9052   GLA Class  2019  23149    Semi-Auto    13359   Diesel  145   67.3
# 7120     C Class  2019  29799    Semi-Auto     9168   Diesel  145   57.7
# 3902     C Class  2019  48990    Semi-Auto      800   Petrol  145   29.1
# 8229     C Class  2019  27499    Semi-Auto     1211   Diesel  145   58.9
# 5318     B Class  2019  22990       Manual      169   Petrol  145   44.8
# 7075     C Class  2019  31400    Semi-Auto      100   Diesel  145   64.2
#
#       engineSize
# 3637         2.0
# 6947         2.1
# 5826         2.0
# 2970         2.0
# 9052         2.1
# 7120         2.0
# 3902         3.0
# ...

# %%
df.info()
# Bu bilan biz 9 ta ustundagi toldirilmagan qatorlarni ko'rishimiz mumkin lekin bu yerda hammasi mukamal yani to'ldirilgan va 13_119 ta malumot bor har birida.
# Va type ham ko'rsatiladi: object - matnli malumot, int64 - sonli, float64 - o'nli malumot
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13119 entries, 0 to 13118
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         13119 non-null  object
#  1   year          13119 non-null  int64
#  2   price         13119 non-null  int64
#  3   transmission  13119 non-null  object
#  4   mileage       13119 non-null  int64
#  5   fuelType      13119 non-null  object
#  6   tax           13119 non-null  int64
#  7   mpg           13119 non-null  float64
#  8   engineSize    13119 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 922.6+ KB

# %%
df.describe() # Bu faqat raqamli statistikani chiqaradi. shuning uchun ham model, transmission, fueltype kabilar yo'q.
# Bunda tasvirlab beradi
# count - nechta qiymat borligini. Yani NaN qiymatga ega bo'lmagan qatorlar soni. hamda buyerda 13119 hammasida qiymat bor.
# mean - o'rtachasini, misol (year: 2017 - o'rtacha hisobda mashinalar 2017 - yilda ishlab chiqarilgan), qolganlari ham huddi shunday
# std - standart og'ishi (standart Deviation) yani year: 2.224709 yaxlitlash (2.2) yani 2 yil pastga yoki yuqoriga og'ishi mumkin. Bunda 2015 va 2019 yillarga, shunda o'rtacha 2017 - yil.
# min - (yearga nisbatan) kamida 1970 yilda ishlab chiqarilgan
# 25% - (yearga nisbatan) mashinalarnin 25% foizi 2016 yilgacha.
# 50% - (pricega nisbatan) mashinalarni 50 foizi 22480 atrofidagi narxda 11842 std (pastga yo yuqoriga og'ishi bilan)
# max - (yearga nisbatan) 2020 - yilda ishlab chiqarilgan 25%, 50%, 75% ham shu kabi.
# Out:
#                year          price        mileage           tax           mpg  \
# count  13119.000000   13119.000000   13119.000000  13119.000000  13119.000000
# mean    2017.296288   24698.596920   21949.559037    129.972178     55.155843
# std        2.224709   11842.675542   21176.512267     65.260286     15.220082
# min     1970.000000     650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000   17450.000000    6097.500000    125.000000     45.600000
# 50%     2018.000000   22480.000000   15189.000000    145.000000     56.500000
# 75%     2019.000000   28980.000000   31779.500000    145.000000     64.200000
# max     2020.000000  159999.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  13119.000000
# mean       2.071530
# std        0.572426
# min        0.000000
# 25%        1.800000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
df['price'].plot.hist(bins=30) # Narx bo'yicha tushish va ko'tarilish diagrammasi
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['year'].plot.hist(bins=30) # yil bo'yicha diagrammasi
# Out:
# <Axes: ylabel='Frequency'>
