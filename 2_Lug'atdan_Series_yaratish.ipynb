# %% [markdown]
# <a href="https://colab.research.google.com/github/sherjahong1r/my-data-sayns-lessons/blob/main/2_Lug'atdan_Series_yaratish.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from pandas import Series

# %%
obj2=Series([6, 3, 4, 5, 1], index=['a', 'b', 'c', 'd', 'e']) # bu orqali Indexlarni o'zimiz yaratamiz

# %%
print(obj2)
# Out:
# a    6
# b    3
# c    4
# d    5
# e    1
# dtype: int64

# %%
np.exp(obj2)
# Out:
# a    403.428793
# b     20.085537
# c     54.598150
# d    148.413159
# e      2.718282
# dtype: float64

# %%
obj2
# Out:
# a    6
# b    3
# c    4
# d    5
# e    1
# dtype: int64

# %%
cars_dict = {'Malibu':40000, 'Lacetti':20000, 'Toyota':45000, 'Mazda':52000, 'Honda':38000}

# %%
type(cars_dict)
# Out:
# dict

# %%
cars1 = Series(cars_dict)

# %%
cars1
# Out:
# Malibu     40000
# Lacetti    20000
# Toyota     45000
# Mazda      52000
# Honda      38000
# dtype: int64

# %%
type(cars1)

# %%
cars1 = Series({'Malibu':40000, 'Lacetti':20000, 'Toyota':45000, 'Mazda':52000, 'Honda':38000})

# %%
cars1
# Out:
# Malibu     40000
# Lacetti    20000
# Toyota     45000
# Mazda      52000
# Honda      38000
# dtype: int64

# %%
'Malibu' in cars1
# Out:
# True

# %%
"Nexia" in cars1
# Out:
# False

# %%
cars1['Toyota']
# Out:
# np.int64(45000)

# %%
cars_dict
# Out:
# {'Malibu': 40000,
#  'Lacetti': 20000,
#  'Toyota': 45000,
#  'Mazda': 52000,
#  'Honda': 38000}

# %%
models = ['Honda', 'Mazda', 'Lacetti', 'Jaguar', 'Malibu', 'Toyota', 'BMW', 'Mercedes'] # Yuqoridagi cars1 ichiga yangi modellar qo'shilib ro'yxat yaratildi

# %%
cars2 = Series(cars_dict, index=models) # Hamda index ni models bo'yicha o'qi va yangi mashinalar narxi bo'lmagani uchun o'rnini non qiladi

# %%
cars2
# Out:
# Honda       38000.0
# Mazda       52000.0
# Lacetti     20000.0
# Jaguar          NaN
# Malibu      40000.0
# Toyota      45000.0
# BMW             NaN
# Mercedes        NaN
# dtype: float64
