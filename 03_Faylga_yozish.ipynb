# %% [markdown]
# <a href="https://colab.research.google.com/github/sherjahong1r/my-data-sayns-lessons/blob/main/03_Faylga_yozish.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Faylga yozish**

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/uzbekistan.csv', index_col=0, names=['hudud','maydon','aholi'])
df
# Out:
#                                         maydon       aholi
# hudud
# Boʻlinishi                     Maydoni (kv.km)     Aholisi
# Andijon viloyati                       4200.00  1899000.00
# Buxoro viloyati                       39400.00  1384700.00
# Fargʻona viloyati                      6800.00  2597000.00
# Jizzax viloyati                       20500.00   910500.00
# Xorazm viloyati                        6300.00  1200000.00
# Namangan viloyati                      7900.00  1862000.00
# Navoiy viloyati                      110800.00   767500.00
# Qashqadaryo viloyati                  28400.00  2029000.00
# Qoraqalpogʻiston Respublikasi        160000.00  1200000.00
# Samarqand viloyati                    16400.00  2322000.00
# Sirdaryo viloyati                      5100.00   648100.00
# Surxondaryo viloyati                  20800.00  1676000.00
# Toshkent viloyati                     15300.00  4450000.00

# %%
df.to_excel("newuzb.xlsx")
# bunda biz yuqoridagi df jadvalni to_excel bilan excel formatga
# o'tkazib newuzb.xlsx deb nomladik. Hamda bu chap tomondagi faylda ko'rinadi

# %%
df1 = pd.read_excel("newuzb.xlsx")
df1
# Yuqoridagi excel faylni o'qiyabmiz
# Out:
#                             hudud           maydon       aholi
# 0                      Boʻlinishi  Maydoni (kv.km)     Aholisi
# 1                Andijon viloyati          4200.00  1899000.00
# 2                 Buxoro viloyati         39400.00  1384700.00
# 3               Fargʻona viloyati          6800.00  2597000.00
# 4                 Jizzax viloyati         20500.00   910500.00
# 5                 Xorazm viloyati          6300.00  1200000.00
# 6               Namangan viloyati          7900.00  1862000.00
# 7                 Navoiy viloyati        110800.00   767500.00
# 8            Qashqadaryo viloyati         28400.00  2029000.00
# 9   Qoraqalpogʻiston Respublikasi        160000.00  1200000.00
# 10             Samarqand viloyati         16400.00  2322000.00
# 11              Sirdaryo viloyati          5100.00   648100.00
# 12           Surxondaryo viloyati         20800.00  1676000.00
# 13              Toshkent viloyati         15300.00  4450000.00

# %%
df1.to_csv("newuzb.csv_1")
# Hamda yana excel dan csv formatiga qaytarib saqladik

# %%
type(df1) # df jadvali dataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
obj = df.maydon
obj
# Bu series obyekti bo'ldi
# Out:
# hudud
# Boʻlinishi                       Maydoni (kv.km)
# Andijon viloyati                         4200.00
# Buxoro viloyati                         39400.00
# Fargʻona viloyati                        6800.00
# Jizzax viloyati                         20500.00
# Xorazm viloyati                          6300.00
# Namangan viloyati                        7900.00
# Navoiy viloyati                        110800.00
# Qashqadaryo viloyati                    28400.00
# Qoraqalpogʻiston Respublikasi          160000.00
# Samarqand viloyati                      16400.00
# Sirdaryo viloyati                        5100.00
# Surxondaryo viloyati                    20800.00
# Toshkent viloyati                       15300.00
# Name: maydon, dtype: object

# %%
type(obj)
# Out:
# pandas.core.series.Series

# %%
obj.to_excel("uzmaydon.xlsx")
# Va buni excel formatda saqladik

# %%
a = pd.read_excel("uzmaydon.xlsx", index_col='hudud')
a
# Buni Series typeda turganda saqlagan edik lekin yana DataFrame qilib ochyabdi
# Out:
#                                         maydon
# hudud
# Boʻlinishi                     Maydoni (kv.km)
# Andijon viloyati                       4200.00
# Buxoro viloyati                       39400.00
# Fargʻona viloyati                      6800.00
# Jizzax viloyati                       20500.00
# Xorazm viloyati                        6300.00
# Namangan viloyati                      7900.00
# Navoiy viloyati                      110800.00
# Qashqadaryo viloyati                  28400.00
# Qoraqalpogʻiston Respublikasi        160000.00
# Samarqand viloyati                    16400.00
# Sirdaryo viloyati                      5100.00
# Surxondaryo viloyati                  20800.00
# Toshkent viloyati                     15300.00

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
# pd.read_csv("uzmaydon.csv", index_col='hudud', squeeze=True)
# squeeze=True bu bilan DataFrame dan Series ko'rinishiga o'tkazilar edi.
# Ammo bu buyruq yangi versiyasidan olib tashlangan

# Shuning uchun pastagi buyruqlardan foydalanildi yana Series qilib ochish uchun.
df_from_excel = pd.read_excel("uzmaydon.xlsx", index_col='hudud')
series_from_excel = df_from_excel['maydon']
series_from_excel
# Out:
# hudud
# Boʻlinishi                       Maydoni (kv.km)
# Andijon viloyati                         4200.00
# Buxoro viloyati                         39400.00
# Fargʻona viloyati                        6800.00
# Jizzax viloyati                         20500.00
# Xorazm viloyati                          6300.00
# Namangan viloyati                        7900.00
# Navoiy viloyati                        110800.00
# Qashqadaryo viloyati                    28400.00
# Qoraqalpogʻiston Respublikasi          160000.00
# Samarqand viloyati                      16400.00
# Sirdaryo viloyati                        5100.00
# Surxondaryo viloyati                    20800.00
# Toshkent viloyati                       15300.00
# Name: maydon, dtype: object

# %%
type(series_from_excel)
# Out:
# pandas.core.series.Series

# %%
df2 = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/merc.csv', index_col=0)
df2
# Out:
#            year  price transmission  mileage fuelType  tax   mpg  engineSize
# model
# SLK        2005   5200    Automatic    63000   Petrol  325  32.1         1.8
# S Class    2017  34948    Automatic    27000   Hybrid   20  61.4         2.1
# SL CLASS   2016  49948    Automatic     6200   Petrol  555  28.0         5.5
# G Class    2016  61948    Automatic    16000   Petrol  325  30.4         4.0
# G Class    2016  73948    Automatic     4000   Petrol  325  30.1         4.0
# ...         ...    ...          ...      ...      ...  ...   ...         ...
# C Class    2020  35999    Automatic      500   Diesel  145  55.4         2.0
# B Class    2020  24699    Automatic     2500   Diesel  145  55.4         2.0
# GLC Class  2019  30999    Automatic    11612   Diesel  145  41.5         2.1
# CLS Class  2019  37990    Automatic     2426   Diesel  145  45.6         2.0
# S Class    2019  54999    Automatic     2075   Diesel  145  52.3         2.9
#
# [13119 rows x 8 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Bunda drive papkasini chaqirib oldik
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df2.to_excel("/content/drive/MyDrive/newcars.xlsx", index=False, columns=['year','price','tax'])
# index=False yani indexdagi ustunni alohida hotirada joy ajratib saqlamaydi hotirani tejashda yordam beradi.
# columns= unga yozgan ustunlarimizni saqlaydi holos bu yerda 3 ta ustunni saqlaydi

# Hamda bu faylni chap tomonda saqlagan fayilimizdagi 3 nuqta ustiga bossak download chiqadi
# va uni ochib exelda ko'rishimiz mumkin saqlagan ustunlarimizni.

# '/content/drive/MyDrive/newcars.xlsx' bu bilan 'newcars.xlsx' ni drive papkasidagi MyDrive ichiga saqlayabmiz

# %%
df2 = pd.read_excel("/content/drive/MyDrive/newcars.xlsx")
df2
# read_excel bilan yuqoridagi 'newcars.xlsx' degan saqlagan faylni ochyabmiz
# Out:
#        year  price  tax
# 0      2005   5200  325
# 1      2017  34948   20
# 2      2016  49948  555
# 3      2016  61948  325
# 4      2016  73948  325
# ...     ...    ...  ...
# 13114  2020  35999  145
# 13115  2020  24699  145
# 13116  2019  30999  145
# 13117  2019  37990  145
# 13118  2019  54999  145
#
# [13119 rows x 3 columns]
