# %% [markdown]
# <a href="https://colab.research.google.com/github/sherjahong1r/my-data-sayns-lessons/blob/main/6_Lug'atdan_Datafreym_yaratish.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Lug'atdan Datafreym yaratish**

# %%
import pandas as pd

# %%
data = {
    'Uzbekistan':{2021:33.9, 2020:33.5, 2019:32.9, 2018:32.5, 2017:31.9},
    'Kazakhstan':{2021:18.9, 2020:18.7, 2019:18.5, 2018:18.3, 2017:18.1, 2016:17.8}
}
df2 = pd.DataFrame(data)
df2
# Out:
#       Uzbekistan  Kazakhstan
# 2021        33.9        18.9
# 2020        33.5        18.7
# 2019        32.9        18.5
# 2018        32.5        18.3
# 2017        31.9        18.1
# 2016         NaN        17.8

# %%
df2.index.name = "Yil"

# %%
df2
# Out:
#       Uzbekistan  Kazakhstan
# Yil
# 2021        33.9        18.9
# 2020        33.5        18.7
# 2019        32.9        18.5
# 2018        32.5        18.3
# 2017        31.9        18.1
# 2016         NaN        17.8

# %%
df2.T
# Out:
# Yil         2021  2020  2019  2018  2017  2016
# Uzbekistan  33.9  33.5  32.9  32.5  31.9   NaN
# Kazakhstan  18.9  18.7  18.5  18.3  18.1  17.8

# %%
df2 = pd.DataFrame(data, index=[2021, 2019, 2017]) # Bu bilan faqat kiritilgan indexlar chiqadi

# %%
df2
# Out:
#       Uzbekistan  Kazakhstan
# 2021        33.9        18.9
# 2019        32.9        18.5
# 2017        31.9        18.1

# %%
df2.T # Bunda T bilan index va ustunlar o'rnini almashtirish mumkin
# Out:
#             2021  2019  2017
# Uzbekistan  33.9  32.9  31.9
# Kazakhstan  18.9  18.5  18.1

# %%
arr = df2.values # Bu bilan array ko'rinishiga ham o'tkazish va np dagi turli amallarni bajarish mumkin

# %%
arr
# Out:
# array([[33.9, 18.9],
#        [32.9, 18.5],
#        [31.9, 18.1]])

# %%
type(arr)
# Out:
# numpy.ndarray
