# %% [markdown]
# <a href="https://colab.research.google.com/github/sherjahong1r/my-data-sayns-lessons/blob/main/20_Dataset_Statistikasi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***STATISTIKA***

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/uzbekistan.csv', index_col=0)
df.columns = ['maydoni', 'aholisi']
df
# Out:
#                                 maydoni    aholisi
# Boʻlinishi
# Andijon viloyati                 4200.0  1899000.0
# Buxoro viloyati                 39400.0  1384700.0
# Fargʻona viloyati                6800.0  2597000.0
# Jizzax viloyati                 20500.0   910500.0
# Xorazm viloyati                  6300.0  1200000.0
# Namangan viloyati                7900.0  1862000.0
# Navoiy viloyati                110800.0   767500.0
# Qashqadaryo viloyati            28400.0  2029000.0
# Qoraqalpogʻiston Respublikasi  160000.0  1200000.0
# Samarqand viloyati              16400.0  2322000.0
# Sirdaryo viloyati                5100.0   648100.0
# Surxondaryo viloyati            20800.0  1676000.0
# Toshkent viloyati               15300.0  4450000.0

# %%
df.sum() # sum bilan umumiy qo'shib chiqaramiz
# Out:
# maydoni      441900.0
# aholisi    22945800.0
# dtype: float64

# %%
df2 = pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/gm_sales.csv", index_col=0)
df2
# Out:
#          2020   2021
# Labo     4521   7542
# Damas   30889  33682
# Spark   16370   6485
# Nexia   41663  14442
# Cobalt  44901  36317
# Gentra  30368  26266

# %%
df2.sum() # Bu qatorlarni qo'shadi
# Out:
# 2020    168712
# 2021    124734
# dtype: int64

# %%
df2.sum(axis=1) # Ustunlar bo'yicha hisoblaydi axis=1 bilan. Yani 2 ta yildagi mashinalar sonini qo'shadi
# Out:
# Labo      12063
# Damas     64571
# Spark     22855
# Nexia     56105
# Cobalt    81218
# Gentra    56634
# dtype: int64

# %%
df2.sum(axis='columns') # columns bu ustun degani, shuning uchun yuqoridagi bilan bir xil vazifani bajaradi
# Out:
# Labo      12063
# Damas     64571
# Spark     22855
# Nexia     56105
# Cobalt    81218
# Gentra    56634
# dtype: int64

# %%
df2.mean(axis=1) # Bu o'rtacha qiymatni chiqaradi yani 2 ta yildagi mashinalarni qo'shib 2 ga bo'ladi
# Out:
# Labo       6031.5
# Damas     32285.5
# Spark     11427.5
# Nexia     28052.5
# Cobalt    40609.0
# Gentra    28317.0
# dtype: float64

# %%
df
# Out:
#                                 maydoni    aholisi
# Boʻlinishi
# Andijon viloyati                 4200.0  1899000.0
# Buxoro viloyati                 39400.0  1384700.0
# Fargʻona viloyati                6800.0  2597000.0
# Jizzax viloyati                 20500.0   910500.0
# Xorazm viloyati                  6300.0  1200000.0
# Namangan viloyati                7900.0  1862000.0
# Navoiy viloyati                110800.0   767500.0
# Qashqadaryo viloyati            28400.0  2029000.0
# Qoraqalpogʻiston Respublikasi  160000.0  1200000.0
# Samarqand viloyati              16400.0  2322000.0
# Sirdaryo viloyati                5100.0   648100.0
# Surxondaryo viloyati            20800.0  1676000.0
# Toshkent viloyati               15300.0  4450000.0

# %%
df.mean() # Bunda maydon va aholining o'rtacha qiymati 04 , 06 degani 4 ta va 6 ta nol bor degani nuqtadan keyin.
# Out:
# maydoni    3.399231e+04
# aholisi    1.765062e+06
# dtype: float64

# %% [markdown]
# Boshqa funksiyalar
# count - NaN bo'lmagan qiymatlar soni
#
# median - qiymatlar medianini hisbolash
#
# mad - mean absolute deviation
#
# prod - barcha qiymatlar ko'paytmasi
#
# var - variance (dispersiya)
#
# std - standart deviation (standart chetlanis)
#
# skew - skewness
#
# kurt - kurtosis
#
# cumsum - cumulative sum
#
# cummin va cummax- cumulative min and max
#
# cumprod - cumulative product
#
# diff - arifmetik farq (difference)
#
# pct_change - percent changes

# %%
df2
# Out:
#          2020   2021
# Labo     4521   7542
# Damas   30889  33682
# Spark   16370   6485
# Nexia   41663  14442
# Cobalt  44901  36317
# Gentra  30368  26266

# %%
df2.median() #  qiymatlar medianini hisbolash
# Out:
# 2020    30628.5
# 2021    20354.0
# dtype: float64

# %%
df2.prod() # barcha qiymatlar ko'paytmasi
# Out:
# 2020      61887297365967808
# 2021    9151971529123863600
# dtype: int64

# %%
df2.var() # variance (dispersiya)
# Out:
# 2020    2.345422e+08
# 2021    1.715435e+08
# dtype: float64

# %%
df2.std() # standart deviation (standart chetlanis)
# Out:
# 2020    15314.770422
# 2021    13097.462319
# dtype: float64

# %%
df2.skew()
# Out:
# 2020   -0.627904
# 2021    0.072719
# dtype: float64

# %%
df2.kurt()
# Out:
# 2020   -0.623062
# 2021   -2.421386
# dtype: float64

# %%
df2.cumsum()
# Out:
#           2020    2021
# Labo      4521    7542
# Damas    35410   41224
# Spark    51780   47709
# Nexia    93443   62151
# Cobalt  138344   98468
# Gentra  168712  124734

# %%
df2.cummin()
# Out:
#         2020  2021
# Labo    4521  7542
# Damas   4521  7542
# Spark   4521  6485
# Nexia   4521  6485
# Cobalt  4521  6485
# Gentra  4521  6485

# %%
df2.cumprod()
# Out:
#                        2020                 2021
# Labo                   4521                 7542
# Damas             139649169            254029644
# Spark         2286056896530        1647382241340
# Nexia     95243988480129390    23791494329432280
# Cobalt -3094298354326234522 -2961271902356813192
# Gentra    61887297365967808  9151971529123863600

# %%
df2.diff()
# Out:
#            2020     2021
# Labo        NaN      NaN
# Damas   26368.0  26140.0
# Spark  -14519.0 -27197.0
# Nexia   25293.0   7957.0
# Cobalt   3238.0  21875.0
# Gentra -14533.0 -10051.0

# %%
df2.pct_change()
# Out:
#             2020      2021
# Labo         NaN       NaN
# Damas   5.832338  3.465924
# Spark  -0.470038 -0.807464
# Nexia   1.545082  1.226985
# Cobalt  0.077719  1.514679
# Gentra -0.323668 -0.276757

# %% [markdown]
# ## New Section

# %%
df
# Out:
#                                 maydoni    aholisi
# Boʻlinishi
# Andijon viloyati                 4200.0  1899000.0
# Buxoro viloyati                 39400.0  1384700.0
# Fargʻona viloyati                6800.0  2597000.0
# Jizzax viloyati                 20500.0   910500.0
# Xorazm viloyati                  6300.0  1200000.0
# Namangan viloyati                7900.0  1862000.0
# Navoiy viloyati                110800.0   767500.0
# Qashqadaryo viloyati            28400.0  2029000.0
# Qoraqalpogʻiston Respublikasi  160000.0  1200000.0
# Samarqand viloyati              16400.0  2322000.0
# Sirdaryo viloyati                5100.0   648100.0
# Surxondaryo viloyati            20800.0  1676000.0
# Toshkent viloyati               15300.0  4450000.0

# %%
df.idxmin() # Aholi va maydoni bo'yicha eng minimum qiymatlarni chiqaradi.
# Out:
# maydoni     Andijon viloyati
# aholisi    Sirdaryo viloyati
# dtype: object

# %%
df.idxmax() # Bu maxsimum qiymatlarni chiqaradi
# Out:
# maydoni    Qoraqalpogʻiston Respublikasi
# aholisi                Toshkent viloyati
# dtype: object

# %%
df['maydoni'].idxmax() # Bu aynan bitta qator bo'yicha maxsimumni chiqaradi
# Out:
# 'Qoraqalpogʻiston Respublikasi'

# %%
df['aholisi'].idxmin() # Aholisi bo'yicha minimum
# Out:
# 'Sirdaryo viloyati'

# %%
df['aholisi'].argmin() # Bu minimum qiymatga teng bo'lgan aholining tartib raqamini ko'rsatadi. 0 dan boshlanganda Sirdaryo 10 - tartibda turibdi
# Out:
# np.int64(10)

# %%
df.iloc[10] # Bu bilan 10 indexda Sirdaryo turganini ko'rish mumkin
# Out:
# maydoni      5100.0
# aholisi    648100.0
# Name: Sirdaryo viloyati, dtype: float64

# %%
df["aholisi"].argmax() # aholining maxsimumini tartib raqamini ko'rsatadi
# Out:
# np.int64(12)

# %%
df.iloc[12]
# Out:
# maydoni      15300.0
# aholisi    4450000.0
# Name: Toshkent viloyati, dtype: float64
