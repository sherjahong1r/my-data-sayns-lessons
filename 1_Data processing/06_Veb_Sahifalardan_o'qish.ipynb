# %% [markdown]
# <a href="https://colab.research.google.com/github/sherjahong1r/my-data-sayns-lessons/blob/main/06_Veb_Sahifalardan_o'qish.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Veb-Sahifalardan o'qish**

# %%
import pandas as pd
import numpy as np

# %%
#tashkent = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/housing_data_08-02-2021.csv')
tashkent = pd.read_html("https://en.wikipedia.org/wiki/Tashkent", storage_options={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'})
len(tashkent)
# Bunda html orqali bir nechta jadvallarni saqlash va ularni bir bir chiqarish ham mumkin
# bu yerda 17 ta jadvaldan tashkil topgan.
# Out:
# 17

# %%
tashkent[0]
# Out:
#                          Tashkent  Toshkent / Тошкент  \
# 0                                        Capital city
# 1                                            Tashkent
# 2   Skyline of Tashkent with Nest OneSupreme Assem...
# 3                                            FlagSeal
# 4                    Nickname: Tosh (lit. 'The rock')
# 5   Motto: Kuch Adolatdadir ("Strength is in Justi...
# 6                                                 NaN
# 7                                    TashkentTashkent
# 8   Coordinates: 41°18′40″N 69°16′47″E﻿ / ﻿41.3111...
# 9                                             Country
# 10                                            Settled
# 11                                          Divisions
# 12                                         Government
# 13                                             • Type
# 14                                            • Hakim
# 15                                               Area
# ...

# %%
tashkent[8]
# Out:
#     Year     Pop. ±% p.a.
# 0   2007  2157100  +0.77%
# 1   2008  2180000  +1.06%
# 2   2009  2206300  +1.21%
# 3   2010  2234300  +1.27%
# 4   2011  2296500  +2.78%
# 5   2012  2309300  +0.56%
# 6   2013  2340900  +1.37%
# 7   2014  2352900  +0.51%
# 8   2015  2371300  +0.78%
# 9   2016  2393200  +0.92%
# 10  2017  2424100  +1.29%
# 11  2018  2464900  +1.68%
# 12  2019  2509900  +1.83%
# 13  2020  2571700  +2.46%
# 14  2021  2694400  +4.77%

# %%
tashkent[16]
# Out:
#   Authority control databases  \
# 0               International
# 1                    National
# 2                  Geographic
# 3                       Other
#
#                        Authority control databases.1
# 0                                VIAFGNDFASTWorldCat
# 1  United StatesFranceBnF dataCzech RepublicSpain...
# 2                                   MusicBrainz area
# 3               IdRefNARAİslâm AnsiklopedisiYale LUX
